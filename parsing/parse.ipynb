# %%
from lyricsgenius import Genius
import re
from tokens import *

#artists = ['Kim Na Young', 'Heize', 'BOL4', 'OOHYO', 'Damons Year', '유라', '비비']
#cnt = 0
artists = ['moonmoon']
cnt = 384

genius = Genius(token)
for a in artists:
    res = genius.search_artist(a)

    for i in range(len(res.__dict__['songs'])):
        lyrics = res.__dict__['songs'][i].__dict__['lyrics']
        title = res.__dict__['songs'][i].title + ' - ' + a
        korean_lyrics = title + '\n' + lyrics
        with open(f'lyrics/{cnt}.txt', 'w') as f:
                f.write(korean_lyrics)
                cnt += 1
# Out:
# Searching for songs by moonmoon...
#
# Changing artist name to 'MoonMoon'
# Song 1: "비행운 (Contrail)"
# Song 2: "물감 (PAINT)"
# Song 3: "결혼 (Marriage)"
# Song 4: "파랑새 (L’oiseau bleu)"
# Song 5: "ROACH"
# Song 6: "인디 (Indie)"
# Song 7: "애월 (Aewol)"
# Song 8: "열기구 (Balloon)"
# Song 9: "모네 (Monet)"
# Song 10: "사람없인 사람으로 못살아요 (People)"
# Song 11: "앙고라 (Angora)"
# Song 12: "나무 (Tree)"
# Song 13: "우아한 세계 (Seoul)"
# Song 14: "호이안 (Hoi An)"
# Song 15: "휴일 (Holiday)"
# Song 16: "미술관 (Museum)"
# Song 17: "에덴 (Eden)"
# Song 18: "디왈리 (Diwali)"
# Song 19: "물고기 (Fish)"
# Song 20: "맘 (Mom)"
# Song 21: "순복씨 (Grand Mother)"
# Song 22: "저녁향 (Evening)"
# Song 23: "곰곰 (Gom Gom)"
# Song 24: "아침 (Morning)"
# Song 25: "FULL"
# Song 26: "Moon, Moon"
# Song 27: "영하 (Zero)"
# Song 28: "아카시아 (Acacia)"
# Song 29: "푸욱 [Poo Ooq] (of moon)"
# Song 30: "푸욱 [Poo Ooq] (of mars)"
# "미술관 (Museum) [Instrumental]" is not valid. Skipping.
# "결혼 (Marriage) [Instrumental]" is not valid. Skipping.
# Done. Found 30 songs.

# %%
def corr_punc(text):
    # Mapping of Korean punctuation to English equivalents
    conversion_mapping = {
        '\u2026': '...', # Horizontal ellipsis
        '\u3001': ',',  # Ideographic comma
        '\u3002': '.',  # Ideographic full stop
        '\u00A0': ' ',  # No-Break Space
        '\u1680': ' ',  # Ogham Space Mark
        '\u180E': ' ',  # Mongolian Vowel Separator
        '\u2000': ' ',  # En Quad
        '\u2001': ' ',  # Em Quad
        '\u2002': ' ',  # En Space
        '\u2003': ' ',  # Em Space
        '\u2004': ' ',  # Three-Per-Em Space
        '\u2005': ' ',  # Four-Per-Em Space
        '\u2006': ' ',  # Six-Per-Em Space
        '\u2007': ' ',  # Figure Space
        '\u2008': ' ',  # Punctuation Space
        '\u2009': ' ',  # Thin Space
        '\u200A': ' ',  # Hair Space
        '\u200B': ' ',  # Zero Width Space
        '\u202F': ' ',  # Narrow No-Break Space
        '\u205F': ' ',  # Medium Mathematical Space
        '\u3000': ' ',  # Ideographic Space
        '\uFEFF': ' ',  # Zero Width No-Break Space
        '\u201C': '"',  # Left double quotation mark
        '\u201D': '"',  # Right double quotation mark
        '\u2018': "'",  # Left single quotation mark
        '\u2019': "'",  # Right single quotation mark
        '\u201A': "'",  # Single low-9 quotation mark
        '\u201B': "'",  # Single high-reversed-9 quotation mark
        '\u2032': "'",  # Prime (used to denote minutes or feet)
        '\u2035': "'",  # Reversed Prime (used to denote seconds or inches)
        '\u02BC': "'",  # Modifier letter apostrophe
        '\u02BB': "'",  # Modifier letter turned comma
        '\uFF07': "'",  # Fullwidth apostrophe
    }

    for special_char, english_char in conversion_mapping.items():
        text = text.replace(special_char, english_char)

    return text

# %%
import json
# read the dictionary title_ids from title_ids.txt
title_ids = {}
with open('title_ids.json', 'r') as f:
    title_ids = json.load(f)

# %%
new_title_ids = {}
for k in title_ids:
    new_title_ids[convert_korean_punctuation(k)] = title_ids[k]
title_ids = new_title_ids

# %%
import re
import os
import regex

folder_path = "lyrics/"
lyrics_dir = "lyrics/"
i = 0
missing_ids = []

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path) and file_path.endswith(".txt"):
        # open the file and read it
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
            text = convert_korean_punctuation(text)
        lines = text.split("\n")
        lyrics = '\n'.join(lines[1:])
        title = convert_korean_punctuation(lines[0])
        # remove english from the last line
        lyrics = lyrics.split('\n')
        lyrics[0] = regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', lyrics[0])[-1]
        lyrics[-1] = regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', lyrics[-1])[0]
        korean_lyrics = '\n'.join(lyrics)
        korean_lyrics = korean_lyrics.strip().replace('\n\n', '\n')
        
        newlines = []
        for line in lyrics:
            if re.search(r'[a-zA-Z\u3040-\u309F\u30A0-\u30FF\u4E00-\u9FFF]', line):
                if not re.search(r'[a-zA-Z\u3040-\u309F\u30A0-\u30FF\u4E00-\u9FFF]', regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', line)[-1]):
                    newlines.append(regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', line)[-1])
                elif not re.search(r'[a-zA-Z\u3040-\u309F\u30A0-\u30FF\u4E00-\u9FFF]', regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', line)[0]):
                    newlines.append(regex.split(r'[a-zA-Z]+|[ぁ-んァ-ン一-龥]|\p{P}', line)[0])
                else: newlines.append('')
            else:
                newlines.append(line)
                
        korean_lyrics = '\n'.join(line.strip() for line in newlines if not re.search(r'[a-zA-Z\u3040-\u309F\u30A0-\u30FF\u4E00-\u9FFF]', line))
        korean_lyrics = '\n'.join(line.strip() for line in korean_lyrics.split('\n') if len(line.split()) > 1)
        if len(korean_lyrics.split('\n')) > len(lines) * .6: 
            if title in title_ids:
                id = title_ids[title]
            else: id = None
            if id == None:
                missing_ids.append(title)
            json_data = {
                "title": title,
                "lyrics": korean_lyrics.split('\n'),
                "video_id": id
            }

            # Write the JSON object to a JSON file
            json_file_path = os.path.join(lyrics_dir, f"{i}.json")
            with open(json_file_path, 'w', encoding='utf-8') as json_file:
                json.dump(json_data, json_file, ensure_ascii=False, indent=2)
            
            i += 1
print("Missing ids: " + str(missing_ids))
print("Total videos: " + str(i))
# Out:
# Missing ids: []
# Total videos: 222

# %%
from googleapiclient.discovery import build
import json
import os
from tokens import api_key1, api_key2, api_key3

youtube = build("youtube", "v3", developerKey=api_key1)

# loop through missing ids
for id in missing_ids:
    # Assuming the song title is the first line in the "lyrics" field
    song_title = id

    # Search for videos for the song title
    search_response = youtube.search().list(
        q=song_title,
        type="video",
        part="id",
        maxResults=1
    ).execute()

    if len(search_response['items']) == 0:
        print(f"No videos found for '{song_title}'")
        continue
    else:
        # add the video id to the json file
        title_ids[song_title] = search_response['items'][0]['id']['videoId']

# %%
with open('title_ids.json', 'w') as f:
    json.dump(title_ids, f, indent=4)

# %%
import json
# loop through lyrics/n.json for n in range(0, 168) and put their video ids in a list
title_ids = {}
for i in range(0, 173):
    with open('lyrics/' + str(i) + '.json', 'r') as f:
        data = json.load(f)
        title = data['title']
        id = data['video_id']
        title_ids[title] = id
#write video_ids to a text file
with open('title_ids.json', 'w') as f:
    json.dump(title_ids, f, indent=4)

# %%
from googleapiclient.discovery import build
import json
import os
from tokens import api_key1, api_key2, api_key3

youtube = build("youtube", "v3", developerKey=api_key1)

folder_path = "lyrics" # Path to the folder containing the JSON files

n_songs = 168
cnt = 168
# Iterate through the files in the specified range
for n in range(0, n_songs):
    file_path = os.path.join(folder_path, f"{n}.json")

    # Check if the file exists
    if os.path.isfile(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            # Assuming the song title is the first line in the "lyrics" field
            song_title = data["title"]
            
            # Search for videos for the song title
            search_response = youtube.search().list(
                q=song_title,
                type="video",
                part="id",
                maxResults=1
            ).execute()

            if len(search_response['items']) == 0:
                print(f"No videos found for '{song_title}'")
                continue
            else:
                # add the video id to the json file
                data["video_id"] = search_response['items'][0]['id']['videoId']
                with open(f"lyrics/{cnt}.json", 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=4)
                    cnt += 1


print("Finished converting videos. Missing ids: " + missing_ids)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[7], line 29
#
#      21 song_title = data["title"]
#
#      23 # Search for videos for the song title
#
#      24 search_response = youtube.search().list(
#
#      25     q=song_title,
#
#      26     type="video",
#
#      27     part="id",
#
#      28     maxResults=1
#
# ---> 29 ).execute()
#
#      31 if len(search_response['items']) == 0:
#
#      32     # No videos found
#
#      33     print(f"No videos found for '{song_title}'")
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#
#     129         logger.warning(message)
#
# --> 130 return wrapped(*args, **kwargs)
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#
#     920     self.headers["content-length"] = str(len(self.body))
#
#     922 # Handle retries for server-side errors.
#
# --> 923 resp, content = _retry_request(
#
#     924     http,
#
#     925     num_retries,
#
#     926     "request",
#
#     927     self._sleep,
#
#     928     self._rand,
#
#     929     str(self.uri),
#
#     930     method=str(self.method),
#
#     931     body=self.body,
#
#     932     headers=self.headers,
#
#     933 )
#
#     935 for callback in self.response_callbacks:
#
#     936     callback(resp)
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#
#     189 try:
#
#     190     exception = None
#
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#
#     192 # Retry on SSL errors and socket timeout errors.
#
#     193 except _ssl_SSLError as ssl_error:
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/httplib2/__init__.py:1724, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#
#    1722             content = b""
#
#    1723         else:
#
# -> 1724             (response, content) = self._request(
#
#    1725                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#
#    1726             )
#
#    1727 except Exception as e:
#
#    1728     is_timeout = isinstance(e, socket.timeout)
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/httplib2/__init__.py:1444, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#
#    1441 if auth:
#
#    1442     auth.request(method, request_uri, headers, body)
#
# -> 1444 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#
#    1446 if auth:
#
#    1447     if auth.response(response, body):
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/httplib2/__init__.py:1396, in Http._conn_request(self, conn, request_uri, method, body, headers)
#
#    1394     pass
#
#    1395 try:
#
# -> 1396     response = conn.getresponse()
#
#    1397 except (http.client.BadStatusLine, http.client.ResponseNotReady):
#
#    1398     # If we get a BadStatusLine on the first try then that means
#
#    1399     # the connection just went stale, so retry regardless of the
#
#    1400     # number of RETRIES set.
#
#    1401     if not seen_bad_status_line and i == 1:
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#
#    1372 try:
#
#    1373     try:
#
# -> 1374         response.begin()
#
#    1375     except ConnectionError:
#
#    1376         self.close()
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#
#     316 # read until we get a non-100 response
#
#     317 while True:
#
# --> 318     version, status, reason = self._read_status()
#
#     319     if status != CONTINUE:
#
#     320         break
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#
#     278 def _read_status(self):
#
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#
#     280     if len(line) > _MAXLINE:
#
#     281         raise LineTooLong("status line")
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#
#     704 while True:
#
#     705     try:
#
# --> 706         return self._sock.recv_into(b)
#
#     707     except timeout:
#
#     708         self._timeout_occurred = True
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#
#    1274     if flags != 0:
#
#    1275         raise ValueError(
#
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#
#    1277           self.__class__)
#
# -> 1278     return self.read(nbytes, buffer)
#
#    1279 else:
#
#    1280     return super().recv_into(buffer, nbytes, flags)
#
#
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#
#    1132 try:
#
#    1133     if buffer is not None:
#
# -> 1134         return self._sslobj.read(len, buffer)
#
#    1135     else:
#
#    1136         return self._sslobj.read(len)
#
#
#
# KeyboardInterrupt:

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import io
from tokens import api_key1, api_key2, api_key3

# Replace with your API key
API_KEY = api_key2

# Replace with the channel ID
CHANNEL_ID = 'UCSs4A6HYKmHA2MG_0z-F0xw'

video_ids = []
captions = []
# Build the YouTube service object
youtube = build('youtube', 'v3', developerKey=API_KEY)

try:
    # Retrieve the videos for the channel
    search_request = youtube.search().list(
        part='id',
        channelId=CHANNEL_ID,
        maxResults=50,
        type='video'
    )
    search_response = search_request.execute()
    for res in search_response['items']:
        if 'videoId' in res['id']:
            video_ids.append(res['id']['videoId'])
        

except HttpError as e:
    print(f'An error occurred: {e}')

# %%
import yt_dlp


def download_korean_captions(video_url, video_id):
    ydl_opts = {
        'quiet': True,
        'writeautomaticsub': True,
        'subtitleslangs': ['zh-Hans'],
        'skip_download': True,
        'outtmpl': f'zh_captions/{video_id}.%(ext)s'
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info_dict = ydl.extract_info(video_url, download=True)
        print(info_dict['requested_subtitles'])
        if info_dict.get('requested_subtitles') and info_dict['requested_subtitles'].get('zh-Hans'):
            print(f"Downloaded captions for video ID: {video_id}")
        else:
            print(f"captions not available for video ID: {video_id}")


for video_id in video_ids:
    print(f"Downloading captions for video ID: {video_id}")
    video_url = f"https://www.youtube.com/watch?v={video_id}"
    download_korean_captions(video_url, video_id)
# Out:
# Downloading captions for video ID: qF4-X_CVul0
# None
# captions not available for video ID: qF4-X_CVul0
# Downloading captions for video ID: hJmew8svS40
# None
# captions not available for video ID: hJmew8svS40
# Downloading captions for video ID: XyPfaFlptS4
# None
# captions not available for video ID: XyPfaFlptS4
# Downloading captions for video ID: EDDPt2VSm2I
# None
# captions not available for video ID: EDDPt2VSm2I
# Downloading captions for video ID: TjOVnvdL34k
# None
# captions not available for video ID: TjOVnvdL34k
# Downloading captions for video ID: 51rXjjy92wU
# None
# captions not available for video ID: 51rXjjy92wU
# Downloading captions for video ID: Jw1x7499TTc
# None
# captions not available for video ID: Jw1x7499TTc
# Downloading captions for video ID: zDKs0dyuh0E
# None
# captions not available for video ID: zDKs0dyuh0E
# Downloading captions for video ID: -myA_1JI85E
# None
# captions not available for video ID: -myA_1JI85E
# Downloading captions for video ID: CvKixMTzwvU
# None
# captions not available for video ID: CvKixMTzwvU
# Downloading captions for video ID: hTgKsu8-baE
# None
# captions not available for video ID: hTgKsu8-baE
# Downloading captions for video ID: L078xB5V15E
# None
# captions not available for video ID: L078xB5V15E
# Downloading captions for video ID: maBj8UrB-AA
# None
# captions not available for video ID: maBj8UrB-AA
# Downloading captions for video ID: ijB0qRHvhZ8
# None
# captions not available for video ID: ijB0qRHvhZ8
# Downloading captions for video ID: gvFuijg1_4I
# None
# captions not available for video ID: gvFuijg1_4I
# Downloading captions for video ID: AydL0j8lha8
# None
# captions not available for video ID: AydL0j8lha8
# Downloading captions for video ID: K3LmgOV5njs
# None
# captions not available for video ID: K3LmgOV5njs
# Downloading captions for video ID: 2ys7b9DGJqo
# None
# captions not available for video ID: 2ys7b9DGJqo
# Downloading captions for video ID: uQKHRUd4r-8
# None
# captions not available for video ID: uQKHRUd4r-8
# Downloading captions for video ID: -rKVzBbjn80
# None
# captions not available for video ID: -rKVzBbjn80
# Downloading captions for video ID: 3TgmqH7YbcY
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573538/ei/AkviZM-6Cq-b2_gP4tuVsAE/ip/198.90.109.216/id/dd3826a87ed86dc6/source/youtube/requiressl/yes/dur/782.520/tts_params/caps%3Dasr%26v%3D3TgmqH7YbcY%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573538%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D8A137A866CC0B6AD0548B5ACE02B8F06CBD91C51.463E333343DCFB00B4C1E48ED7851B7756372922%26key%3Ddg_yt0/hls_chunk_host/rr1---sn-q4flrnes.googlevideo.com/mh/dL/mm/31,29/mn/sn-q4flrnes,sn-q4fl6n66/ms/au,rdu/mv/m/mvi/1/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/2/short_key/1/keepalive/yes/fexp/24007246,51000011,51000023/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIhALld3oJko8jN7Womlckssl2cs1eyF8cfwwv5ZMxjiaDlAiA1TUQOurebi1HUq0sQ80TU_BpkTwwqQS4Vjx3b7rOkjg%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAIPMR_Cs9G9KRbgYt13EqqX4jHhEIs3inLoQz99TWhTZAiEA1mR0W6Uytl5uyGAhrc4N7gh3anyg-Sufd_zHqgVL3jw%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/3TgmqH7YbcY.zh-Hans.vtt'}}
# Downloaded captions for video ID: 3TgmqH7YbcY
# Downloading captions for video ID: AbMTG8bzVfY
# {}
# captions not available for video ID: AbMTG8bzVfY
# Downloading captions for video ID: g_fSistU3MQ
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573541/ei/BUviZKOjFoKhlu8Pms-04A0/ip/198.90.109.216/id/83f7d28acb54dcc4/source/youtube/requiressl/yes/dur/1002.600/tts_params/caps%3Dasr%26v%3Dg_fSistU3MQ%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573541%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D76E2C77B43F6F1BF51FE6A7E2FFBACFD183B3D52.6D52E77F8726F87ACA9643DD5CDB25E957E7DA28%26key%3Ddg_yt0/hls_chunk_host/rr5---sn-q4fl6nd7.googlevideo.com/mh/Bs/mm/31,26/mn/sn-q4fl6nd7,sn-5uaezned/ms/au,onr/mv/m/mvi/5/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246,51000023/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRgIhAN-0hIq1rYpGkT6gglcAcyzqn5kgF4Y0wGUtTbvquNvfAiEAwArrxtzYGPS6EIZH5n9_bRaR9mQMB9gBy0ptv6ojYJA%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAI0dsJJwfL-8jtViKBZ0cYPoe3XSkqVfN4R3IIiRoi6hAiEA4BU6wNEA8iFBemMs4xs0TN-zmgqIw3vNIzdtoptQkI8%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/g_fSistU3MQ.zh-Hans.vtt'}}
# Downloaded captions for video ID: g_fSistU3MQ
# Downloading captions for video ID: tVBwxHQKO14
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573544/ei/CEviZMr3EPyrlu8PvPWm4A0/ip/198.90.109.216/id/b55070c4740a3b5e/source/youtube/requiressl/yes/dur/841.960/tts_params/caps%3Dasr%26v%3DtVBwxHQKO14%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573544%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D0C5AA506BAA65F7FAC7C4D3615B5730B112B5179.3F6E2802CCCFDB21640C93E735E8BECA862DC3A5%26key%3Ddg_yt0/hls_chunk_host/rr1---sn-q4fl6nsd.googlevideo.com/mh/qI/mm/31,29/mn/sn-q4fl6nsd,sn-q4flrnss/ms/au,rdu/mv/m/mvi/1/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/3/short_key/1/keepalive/yes/fexp/24007246,24363392/beids/24350017/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgL_oX4fuWqmRmwZlIgKcoi1KWH9T3188LHadkgX77p4QCIEWlpkTJNZbXROOokLVW04u0T6MM-MgScG1oGS7LVPu1/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIhALcKi0MHC8YlDo3cRqVySjCFs2odXiWDYNxSCiQC5f1EAiBDO-Hd7L_eU7jO2Ir6gE3eiKFmsJbbNZ63ms4IpFZFtA%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/tVBwxHQKO14.zh-Hans.vtt'}}
# Downloaded captions for video ID: tVBwxHQKO14
# Downloading captions for video ID: _8PYYnuoZP8
# {}
# captions not available for video ID: _8PYYnuoZP8
# Downloading captions for video ID: 4vbcC4TcMGc
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573547/ei/C0viZJD_KaKP2_gPv9OBmA8/ip/198.90.109.216/id/e2f6dc0b84dc3067/source/youtube/requiressl/yes/dur/682.214/tts_params/caps%3Dasr%26v%3D4vbcC4TcMGc%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573547%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D1580BF82FF9A2A3F722F5E1089798607361FA4EB.20CC3B8452CB730AB66869C6DFC6B5B70634CC0B%26key%3Ddg_yt0/hls_chunk_host/rr2---sn-q4fl6n6y.googlevideo.com/mh/hv/mm/31,29/mn/sn-q4fl6n6y,sn-q4flrnld/ms/au,rdu/mv/m/mvi/2/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246,24362685,51000024/beids/24350017/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgU7H5v3F5-dCtUzfeTSNMTK7i1DXh98oXyJciCqPHWMECIHTeeMbxRm_K0niA8OeX8pfPRUS3WJTowHc9rJVuuS8n/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRAIgWguBHJS914iiA5vJZkzpzcI6Wfwwz4OaPfrYhGkgf0cCIEwsyhLUMz3aEzVyZ5RZd5yto5EH5XlLMYTlR2fD-vKG/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/4vbcC4TcMGc.zh-Hans.vtt'}}
# Downloaded captions for video ID: 4vbcC4TcMGc
# Downloading captions for video ID: Br_OQ0Zznz4
# {}
# captions not available for video ID: Br_OQ0Zznz4
# Downloading captions for video ID: 6L37Nwffy74
# {}
# captions not available for video ID: 6L37Nwffy74
# Downloading captions for video ID: VhunpYlc2Eo
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573552/ei/EEviZJ7FG6WK2_gPs7WIqAY/ip/198.90.109.216/id/561ba7a5895cd84a/source/youtube/requiressl/yes/dur/764.440/tts_params/caps%3Dasr%26v%3DVhunpYlc2Eo%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573552%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D70CB38D9FF2345D61E423953471D73FC96AFCDD9.58CC804A78D10F869FA11C5396E772D8427B678F%26key%3Ddg_yt0/hls_chunk_host/rr4---sn-q4fl6n6r.googlevideo.com/mh/o_/mm/31,29/mn/sn-q4fl6n6r,sn-q4fzen7e/ms/au,rdu/mv/m/mvi/4/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgUXt4-VfsaFbPy2njD6nkb1jlZ6-f8BOUdSmGoOtcxFMCIG26HK6x1G0mCcQRvL35EZQT9D51HYqt7UcFiddM9McW/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAKNo17MEvDIwWmXpakOU-AyH9WrEfYut5TDOpIcrMCqJAiEAlEnkS7WdSmMpvPltwy4ApsIPPI9vQYgs3KfDJ8KjG8E%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/VhunpYlc2Eo.zh-Hans.vtt'}}
# Downloaded captions for video ID: VhunpYlc2Eo
# Downloading captions for video ID: adXAcQTvXXA
# None
# captions not available for video ID: adXAcQTvXXA
# Downloading captions for video ID: g-wCpEZBEdw
# None
# captions not available for video ID: g-wCpEZBEdw
# Downloading captions for video ID: Go-NplqS05A
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573556/ei/FEviZNrwONihlu8PpOKs2AQ/ip/198.90.109.216/id/1a8f8da65a92d390/source/youtube/requiressl/yes/dur/820.766/tts_params/caps%3Dasr%26v%3DGo-NplqS05A%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573556%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D0B6394F35B953A824B97DC94FC21B4A5A31EEE42.960EABE7CAE4D18AFA3FA2F6EF4EC130AD3823A1%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4flrn7y.googlevideo.com/mh/AD/mm/31,29/mn/sn-q4flrn7y,sn-q4fl6n66/ms/au,rdu/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/4/short_key/1/keepalive/yes/fexp/24007246/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIhALN3puox9Pl96f2vqIjQEhp21aqV0wBsv13GTKxBV4oYAiAoImpH1KdFqFBFcQrwc53d_nuFJkforNMSdXLjT3u47g%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAKIcHOEa9ds9ON3YhMzabsSDmyGJrBHPsCMdqXkOzX2HAiEA8GLw0fn2XTNEh-6BdRhPMjFqEga9xK-GqwNSMkbyoGY%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/Go-NplqS05A.zh-Hans.vtt'}}
# Downloaded captions for video ID: Go-NplqS05A
# Downloading captions for video ID: OpQo58RuByI
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573558/ei/FkviZJ6rL8fClu8P8OimsAw/ip/198.90.109.216/id/3a9428e7c46e0722/source/youtube/requiressl/yes/dur/469.520/tts_params/caps%3Dasr%26v%3DOpQo58RuByI%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573558%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D33C5D3CCDE875F49F8EF16A9B9F16A3078FBFDB2.8252075AB1EE832423DA6ED4DAEAFFC4C7FACDBA%26key%3Ddg_yt0/hls_chunk_host/rr4---sn-q4fl6nsr.googlevideo.com/mh/Sk/mm/31,26/mn/sn-q4fl6nsr,sn-5ualdnsl/ms/au,onr/mv/m/mvi/4/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/4/short_key/1/keepalive/yes/fexp/24007246,24363391/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgAVQHA-xwOV5mY8R_yVEUe7JzbX_8Vy-y5Mi8vjecI8MCIHRdgPpucJeREiwzui6UXwy4JkTiMOFriSFjDgA-B3iX/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIhAP7hfFNv8-oqdt51fh6e6lVa48o5mf5E_rujzdHvyte0AiAqJv-Wl317ZDozsXL1BdUlOIllKbWhuDXzaorEqAZ9iQ%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/OpQo58RuByI.zh-Hans.vtt'}}
# Downloaded captions for video ID: OpQo58RuByI
# Downloading captions for video ID: 3hIqEis4d9I
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573560/ei/GEviZNT4JdShlu8P-p-N-A8/ip/198.90.109.216/id/de122a122b3877d2/source/youtube/requiressl/yes/dur/878.600/tts_params/caps%3Dasr%26v%3D3hIqEis4d9I%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573560%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D3E9B2583F3C1BFB45FE06FA3A65F838AA0B2F533.4489B8947B2A9EDCA52D83B370E744297FD5A492%26key%3Ddg_yt0/hls_chunk_host/rr2---sn-q4flrney.googlevideo.com/mh/2q/mm/31,26/mn/sn-q4flrney,sn-5uaeznly/ms/au,onr/mv/m/mvi/2/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246,51000022/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgcTGJYYrzs4uonEGfM4qRYoGt6KT27ANY52etUrT4sFwCIC1Q3z25XmLq2Q0EixhujkysYd6ekuSdU52d9_AtAdsV/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIgJbS1p9DhrFQM9-hXrMsnCjl_Zc54_DMzoRyFWpGXu1oCIQCM6HYlRyeMGAL3rWegg8lCMAE4uzD9KoMgaxrU-X-RAA%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/3hIqEis4d9I.zh-Hans.vtt'}}
# Downloaded captions for video ID: 3hIqEis4d9I
# Downloading captions for video ID: pbAVauYsqP0
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573562/ei/GkviZM2lFpK_lu8P4Ni-0AQ/ip/198.90.109.216/id/a5b0156ae62ca8fd/source/youtube/requiressl/yes/dur/954.080/tts_params/caps%3Dasr%26v%3DpbAVauYsqP0%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573562%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D07355E983D0500C688D3D1DFDB5D1C7BC4F3C563.4FFFCFCCE038F57D47E59B37D01B1C4DAA1D5E6D%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4fl6nd7.googlevideo.com/mh/2w/mm/31,29/mn/sn-q4fl6nd7,sn-q4flrnss/ms/au,rdu/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/5/short_key/1/keepalive/yes/fexp/24007246/beids/24350017/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgNc0OgMGcad2z0x_Y1btL1gYIQq66JdCP622nGkVQY_ECIQDIlqEVJkugFV9XbVcxvnCoGFjhNPHiWdnnXKp6EN3VjA%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIhAKytr38V4wk-u2SZqHmYay649nUp9xrHsMLZthq2Mj8AAiBgrNEzD-2DAAQNYplW3Pu2xK15nmRFV8CrYaOZH4EbZA%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/pbAVauYsqP0.zh-Hans.vtt'}}
# Downloaded captions for video ID: pbAVauYsqP0
# Downloading captions for video ID: uLUmFYPugEE
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573564/ei/HEviZM-rBt-Vlu8P1pGe8AQ/ip/198.90.109.216/id/b8b5261583ee8041/source/youtube/requiressl/yes/dur/1005.160/tts_params/caps%3Dasr%26v%3DuLUmFYPugEE%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573564%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D7CD30AD27CA1FF06D3B7D82753E5978DD6D1F9A2.4B0E8B8AF0DD64FADDAFAC9EE61E7A37089A2878%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4fzen7y.googlevideo.com/mh/Fq/mm/31,26/mn/sn-q4fzen7y,sn-5uaeznlr/ms/au,onr/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/3/short_key/1/keepalive/yes/fexp/24007246/beids/24472448/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgYsKvUWMFjYsc6xYJv7lrh3b7Wps43lnAlbLqP-hDHrYCIQDnJOgnO71imGV9JkiCuffT1M201ulaeFMpC1vl4K9p-w%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRAIgP83if6FMPPzlKW1Hw2A5yRu17jOMe-b_oRAMhFL_-kcCIFs16fMQ4GC1c5m8RwuLXRvbzF0R-WUUjPTdOOg4pyTx/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/uLUmFYPugEE.zh-Hans.vtt'}}
# Downloaded captions for video ID: uLUmFYPugEE
# Downloading captions for video ID: eaLWMHtK8gc
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573565/ei/HUviZJb2MrWflu8P-rCLuA4/ip/198.90.109.216/id/79a2d6307b4af207/source/youtube/requiressl/yes/dur/352.000/tts_params/caps%3Dasr%26v%3DeaLWMHtK8gc%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573565%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D9AC8BF57578F9C515DBF902FF97F5DE2A27892AE.1ED567832675A3191FDFE9E6E93C43DB94586D6C%26key%3Ddg_yt0/hls_chunk_host/rr5---sn-q4flrn7y.googlevideo.com/mh/Ud/mm/31,29/mn/sn-q4flrn7y,sn-q4fl6n6z/ms/au,rdu/mv/m/mvi/5/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/5/short_key/1/keepalive/yes/fexp/24007246,24363391/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgJvO2NBuAUVU71gwnhcAOd65bJ-LTIbRypQa49Y3J85oCIQC4hWIGbi738kd_9MzDI0mpVMqY1ItWPz6ugzvrscH8tQ%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIgSXfiUfNKWQh3h0pdnB5djXuEOnC-_LxX8fTmZVVCFfwCIQCf9RAgR3MuXf0vUbkvRKkMps-RweL9Cd8OXiVprzhqyw%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/eaLWMHtK8gc.zh-Hans.vtt'}}
# Downloaded captions for video ID: eaLWMHtK8gc
# Downloading captions for video ID: IUDIz1WwBXg
# {}
# captions not available for video ID: IUDIz1WwBXg
# Downloading captions for video ID: zSX0YYSmiT0
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573568/ei/IEviZKy5N-Kalu8PoJ6ngAY/ip/198.90.109.216/id/cd25f46184a6893d/source/youtube/requiressl/yes/dur/1240.880/tts_params/caps%3Dasr%26v%3DzSX0YYSmiT0%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573568%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D10C8CB7EC7394BEF6B2B09BC41799304269371D3.1F3C063B0B33233198D370192418C8DDA37E24E8%26key%3Ddg_yt0/hls_chunk_host/rr5---sn-q4fl6nzy.googlevideo.com/mh/XM/mm/31,26/mn/sn-q4fl6nzy,sn-5uaeznly/ms/au,onr/mv/m/mvi/5/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/4/short_key/1/keepalive/yes/fexp/24007246,51000023/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgCDQiR-w-_8uAno_S5XylEER8HllAQTEPc_ZPWg4MjdgCIA7UHWa4TIfvPdRJgnpe_hNyKPy1Ex3YqWcTd7FY4Dz3/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIhANmmOOGMHjDgMBPG2FmFZ1_4dRV4SML2OkNSuRfG4A6jAiB1Ind1s6S83VM-SdOoycl05XXSg0U6i7imnDnrIl-wPg%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/zSX0YYSmiT0.zh-Hans.vtt'}}
# Downloaded captions for video ID: zSX0YYSmiT0
# Downloading captions for video ID: deBr1ybSf_8
# None
# captions not available for video ID: deBr1ybSf_8
# Downloading captions for video ID: FtLj8WUcqow
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573572/ei/I0viZNWMPPKM2_gPmZ2Y8AQ/ip/198.90.109.216/id/16d2e3f1651caa8c/source/youtube/requiressl/yes/dur/717.080/tts_params/caps%3Dasr%26v%3DFtLj8WUcqow%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573572%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D8395A33CDCBCD82D3753185150E957DFC89C39F4.1A3FE35F1B2A51A5E2DD02677926CFC4C5A129D1%26key%3Ddg_yt0/hls_chunk_host/rr1---sn-q4fl6nds.googlevideo.com/mh/Nc/mm/31,26/mn/sn-q4fl6nds,sn-5ualdnsd/ms/au,onr/mv/m/mvi/1/pl/24/pcm2/yes/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/3/short_key/1/keepalive/yes/fexp/24007246/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,pcm2,vprv,playlist_type/sig/AOq0QJ8wRQIhAICsraIG1_MQA5UmrCf04Is9kZ6M8Ht18wce2LWaQQmKAiBcSSKn2iu2WxaKUgsyrSwS-wR8YCK-dhMN8AzFyssFuQ%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAM057B0r9v_zAG-HoF-UEgHz9Ko_nhh3EyEXKfOmRixVAiEA92POyWf1NwLR6nxpOiG8hWwzKllxF-bg2OiFxSi5vVs%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/FtLj8WUcqow.zh-Hans.vtt'}}
# Downloaded captions for video ID: FtLj8WUcqow
# Downloading captions for video ID: PXseMoyGKzY
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573573/ei/JUviZLH6MoSL2_gPiO2hqAM/ip/198.90.109.216/id/3d7b1e328c862b36/source/youtube/requiressl/yes/dur/1118.080/tts_params/caps%3Dasr%26v%3DPXseMoyGKzY%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573573%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D8D4DA5492DE40C519D9E2DBF570B6F694BA82A9C.3742FCA0FFCE70754081197CE92985E3FCC5F425%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4flrnle.googlevideo.com/mh/RS/mm/31,26/mn/sn-q4flrnle,sn-5uaeznsl/ms/au,onr/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/3/short_key/1/keepalive/yes/fexp/24007246/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgSXaQssLfVT3SSh54sAsEZnVvMUwPwAputYDCkhhkwIcCIGqvP_anvNAAUMcXZbhjNMiwASSF3yA6t7JdOGMkkgX4/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIgZ2GRR4UkSIX4bY9HExa3xtd8VvKaG7D9ZhUeHMHqdo0CIQDYt6wtcw_nAn5L4KZzDrHp61pVasgzbjhaaJWutGmzbg%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/PXseMoyGKzY.zh-Hans.vtt'}}
# Downloaded captions for video ID: PXseMoyGKzY
# Downloading captions for video ID: E9KZ9ijFMqc
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573575/ei/J0viZICdK-2flu8P5_uUiAs/ip/198.90.109.216/id/13d299f628c532a7/source/youtube/requiressl/yes/dur/727.360/tts_params/caps%3Dasr%26v%3DE9KZ9ijFMqc%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573575%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D936D0568CF68917A37EB474B276B46B7CA0988F2.4655B572579B0C2DD5251FF3D3FAF1A758CB0F6E%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4fzen7s.googlevideo.com/mh/Nm/mm/31,29/mn/sn-q4fzen7s,sn-q4fl6ns7/ms/au,rdu/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246,51000011/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRAIgNgbsUsPdSBwR4KtriBgY_rCFkPcoPwquwdzIuka6ii8CID1mC4R5cvpbX5Rsd22kW9-HLouJQ_mhD4GOXFCmzxLv/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRgIhAJC6ktKByVREIv2QMCnTnGbR0frvM_4Iv7x6vQCVkPQdAiEAi0Ln3Sgc-C9j-UzU_9N8ZPUZIeJpqnhdsv1OO-lUxnA%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/E9KZ9ijFMqc.zh-Hans.vtt'}}
# Downloaded captions for video ID: E9KZ9ijFMqc
# Downloading captions for video ID: b7NZfkqFc6k
# {}
# captions not available for video ID: b7NZfkqFc6k
# Downloading captions for video ID: iFWsUUSNoe8
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573579/ei/K0viZJalCYXG1AG76KOIBQ/ip/198.90.109.216/id/8855ac51448da1ef/source/youtube/requiressl/yes/dur/514.066/tts_params/caps%3Dasr%26v%3DiFWsUUSNoe8%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573579%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D50CD32CD6279A2666EC7297C8CE4BB94EAA2E7CB.20B25ED993ACECC28C41355BE36FABA26983BDBB%26key%3Ddg_yt0/hls_chunk_host/rr4---sn-q4flrn7k.googlevideo.com/mh/bH/mm/31,26/mn/sn-q4flrn7k,sn-5ualdns7/ms/au,onr/mv/m/mvi/4/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/1/short_key/1/keepalive/yes/fexp/24007246,24362685,51000024/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIhAM_1vw7ElDD9YsP5fFn4ReyC0oo5FmxRDlaOREJSVowEAiBGnYqA9LoeEc1K0K7Q-lIzzVLTFNT-0RvnZzpW8_MYWQ%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIgG82yX7GVO48IIATP4A1gP6F1us7rNl95o1PmnVKZci8CIQCdQQcc0UQrj3pMwIosZlz4bq6JpKFYaeA9zSjwEq6Fjw%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/iFWsUUSNoe8.zh-Hans.vtt'}}
# Downloaded captions for video ID: iFWsUUSNoe8
# Downloading captions for video ID: y5coTWUm39M
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573580/ei/LEviZMuIMtiylu8PwfS2wA4/ip/198.90.109.216/id/cb97284d6526dfd3/source/youtube/requiressl/yes/dur/756.240/tts_params/caps%3Dasr%26v%3Dy5coTWUm39M%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573580%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D6D1AA3B90E381F6154295A64E130ABA00BCDADA1.4135BCC0B8944BA317388F5DB630D49697D6D8D7%26key%3Ddg_yt0/hls_chunk_host/rr1---sn-q4fl6nsr.googlevideo.com/mh/hZ/mm/31,29/mn/sn-q4fl6nsr,sn-q4flrnsl/ms/au,rdu/mv/m/mvi/1/pl/24/initcwndbps/2256250/vprv/1/playlist_type/DVR/mt/1692551828/fvip/4/short_key/1/keepalive/yes/fexp/24007246,51000022/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgEfLsl6NDiz6bJsRAM9RrFlijBoyvDw8yZGsNRUSnjEMCIQDdmd7fxfPRe1esjcOoP-T0wYXmrUQk4OkXUSRKYV_oHg%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRAIgV-FgMT-5q_QwOvLsA4PLjmCdjPc2d4WoZ6Tc6LmNCdgCIE2mkN419fKUsAH2xvkfAc_gCwq5dGlMK9lSGpOp7elW/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/y5coTWUm39M.zh-Hans.vtt'}}
# Downloaded captions for video ID: y5coTWUm39M
# Downloading captions for video ID: ii1fTxhD_D0
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573582/ei/LkviZPCWNLWZ2_gP3OOryAQ/ip/198.90.109.216/id/8a2d5f4f1843fc3d/source/youtube/requiressl/yes/dur/1445.040/tts_params/caps%3Dasr%26v%3Dii1fTxhD_D0%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573582%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D713A6789638EBAC56DC35249B18D68AF486C1F3D.894C1E1082A8862651FA12975AA715960CE06E66%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4fl6n6r.googlevideo.com/mh/-Q/mm/31,26/mn/sn-q4fl6n6r,sn-5ualdnze/ms/au,onr/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/4/short_key/1/keepalive/yes/fexp/24007246,24362685/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgG9kLAufHaXtM8oHzhYh_vazyjQn4LK59l1wJKTHbiLACIQDN4uEfJ-2w6WeYnZV1q676jS9XIOJmShQ193GwYNtfSg%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIgLOgXK07sZP5cjUSyvYHHwe6Zz2Da4xO8Q47Q_5ASVIUCIQCkbgGiJ7ab7hMejQKvxMiw4jNHEg0hGrmg5RHdB9ia0w%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/ii1fTxhD_D0.zh-Hans.vtt'}}
# Downloaded captions for video ID: ii1fTxhD_D0
# Downloading captions for video ID: OTe3Bbcixow
# {}
# captions not available for video ID: OTe3Bbcixow
# Downloading captions for video ID: NeoDdnSlRjk
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573585/ei/MUviZMrcN6PQlu8PgMO28AU/ip/198.90.109.216/id/35ea037674a54639/source/youtube/requiressl/yes/dur/1009.541/tts_params/caps%3Dasr%26v%3DNeoDdnSlRjk%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573585%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D53A192E7436DD09C90CE064FCC8D8147A450979B.9076E64BF02E6D75B7A8523301BA0D9E06FBD0E2%26key%3Ddg_yt0/hls_chunk_host/rr3---sn-q4fl6nde.googlevideo.com/mh/t0/mm/31,26/mn/sn-q4fl6nde,sn-5uaeznze/ms/au,onr/mv/m/mvi/3/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/2/short_key/1/keepalive/yes/fexp/24007246/beids/24350018/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIgN8V51KFsuezhfcmC7qWKD0ririR1W4mcQTzaqw_ysogCIQCwIczTRwnrgBPYfOTO2enGlVo3QIV6GvQRZ6YZeCIlXg%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRAIgaLAazP0d2h13gp5yLNU0lOn1h2jJHwiu2xmd-uiDbeECID7Oplh6jJQdIxOxVA-Ne7vNzUXTOLbo41FXv_OQ72Tw/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/NeoDdnSlRjk.zh-Hans.vtt'}}
# Downloaded captions for video ID: NeoDdnSlRjk
# Downloading captions for video ID: gtFSBftabeU
# {'zh-Hans': {'url': 'https://manifest.googlevideo.com/api/manifest/hls_timedtext_playlist/expire/1692573587/ei/M0viZIzIIs-glu8P5JeCgAY/ip/198.90.109.216/id/82d15205fb5a6de5/source/youtube/requiressl/yes/dur/1198.480/tts_params/caps%3Dasr%26v%3DgtFSBftabeU%26lang%3Dzh-Hans%26ip%3D198.90.109.216%26ipbits%3D0%26expire%3D1692573587%26sparams%3Dip,ipbits,expire,caps,v%26signature%3D756B4868CC9B203347790DFE376A0E870D0C58CC.5E290BA1F466461725C97B13D258A343152E7427%26key%3Ddg_yt0/hls_chunk_host/rr4---sn-q4flrnek.googlevideo.com/mh/X8/mm/31,26/mn/sn-q4flrnek,sn-5uaeznss/ms/au,onr/mv/m/mvi/4/pl/24/initcwndbps/2528750/vprv/1/playlist_type/DVR/mt/1692551581/fvip/2/short_key/1/keepalive/yes/fexp/24007246,24362685,51000023/sparams/expire,ei,ip,id,source,requiressl,dur,tts_params,vprv,playlist_type/sig/AOq0QJ8wRQIhAKtPDeDUkI0AEPk8fVtV3ItyoUanbCxkOAUA7e6K_kPbAiBWnCaY1Oim9bs5YzLuJo9ew0FEmbudjNtEadCtfKZibQ%3D%3D/lsparams/hls_chunk_host,mh,mm,mn,ms,mv,mvi,pl,initcwndbps/lsig/AG3C_xAwRQIhANmkce8lRIjXVuCvnmbMCd0TYPdQqgKeXxD0YUEv23e1AiBPxytn-6ntXBYU7vTPDaVWhOGGxqyJxnnFbmoB_mqt0w%3D%3D/playlist/index.m3u8', 'ext': 'vtt', 'protocol': 'm3u8_native', 'filepath': 'zh_captions/gtFSBftabeU.zh-Hans.vtt'}}
# Downloaded captions for video ID: gtFSBftabeU

# %%
import subprocess

video_url = 'https://www.youtube.com/watch?v=X8IiFXdkhlo'

video_id = video_url.split('v=')[-1]
print("Video ID:", video_id)


# Download captions in English (en) as an SRT file without downloading the video
subprocess.run(['yt-dlp', '--skip-download', '--write-sub', '--sub-lang', 'en', video_url])
# Out:
# Video ID: X8IiFXdkhlo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X8IiFXdkhlo
# [youtube] X8IiFXdkhlo: Downloading webpage
# [youtube] X8IiFXdkhlo: Downloading ios player API JSON
# [youtube] X8IiFXdkhlo: Downloading android player API JSON
# [youtube] X8IiFXdkhlo: Downloading m3u8 information
# [info] X8IiFXdkhlo: Downloading subtitles: en
# [info] X8IiFXdkhlo: Downloading 1 format(s): 22
# [info] Writing video subtitles to: 넷플릭스 보고 몸이 바뀌었다 [X8IiFXdkhlo].en.vtt
# [download] Destination: 넷플릭스 보고 몸이 바뀌었다 [X8IiFXdkhlo].en.vtt
# [download] 100% of   12.55KiB in 00:00:00 at 286.53KiB/s
# CompletedProcess(args=['yt-dlp', '--skip-download', '--write-sub', '--sub-lang', 'en', 'https://www.youtube.com/watch?v=X8IiFXdkhlo'], returncode=0)

# %%
import re
import os
import regex
import json
import jieba

succ_ids = []
folder_path = "zh_captions/"

def process_caption_line(line):
    # Replace '</c>' followed by any character or number with a space
    processed_line = re.sub(r'</c>.', ' ', line)
    # Replace multiple spaces with a single space
    processed_line = re.sub(r'\s+', ' ', processed_line).strip()
    return processed_line

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path) and file_path.endswith(".vtt"):

        # Extract video ID from the file path
        video_id = os.path.basename(file_path).split('.')[0]

        # Read the caption file
        with open(file_path, 'r', encoding='utf-8') as file:
            captions = []
            lines = file.readlines()
            for i, line in enumerate(lines):
                if '-->' in line:
                    l = corr_punc(lines[i+1]).strip()
                    #use jieba to split it into words
                    l = ' '.join(jieba.cut(l))
                    captions.append(l)
                
        # Create a JSON object
        caption_json = {
            'video_id': video_id,
            'captions': captions
        }

        # Print the JSON object
        print(json.dumps(caption_json, ensure_ascii=False, indent=2))

        # Optionally, you can save the JSON object to a file
        with open(f'zh_captions/{video_id}.json', 'w', encoding='utf-8') as file:
            json.dump(caption_json, file, ensure_ascii=False, indent=2)
            succ_ids.append(video_id)
# Out:
# {
#   "video_id": "iFWsUUSNoe8",
#   "captions": [
#     "各位 同学 大家 好",
#     "我 是 李永乐 老师",
#     "今天 由 我 继续 为 大家 导读",
#     "爱因斯坦 的 小册子",
#     "《 狭义 与 广义 相对论 浅 说 》",
#     "在 爱因斯坦 年轻 时候",
#     "特别 喜欢 读书",
#     "比如 他 阅读 了 很多 庞加莱 的 著作",
#     "庞加莱 是 高斯 和 黎曼 之后",
#     "世界 上 最 伟大 的 数学家 之一",
#     "他 的 许多 工作 对 相对论 的 提出",
#     "产生 了 重要 影响",
#     "甚至 一度 有人 认为",
#     "庞加莱 才 是 相对论 的 提出 者",
#     "同时   庞加莱 是 一名 科学 哲学家",
#     "他 曾经 写过 一本 小册子",
#     "《 科学 与 假设 》",
#     "在 这 本书 中",
#     "庞加莱 提出",
#     "想 把 两个 不 在 一起 的 时钟 对齐",
#     "并 不是 一件 容易 的 事",
#     "比如   在 北京 有 一个 钟表",
#     "在 上海 有 另 一个 钟表",
#     "我们 通过 什么 方法 能 将 两个 钟表 对准 呢",
#     "大家 注意",
#     "你 不能 回答 我 说 打开 电脑",
#     "查询 标准 北京 时间",
#     "因为 能够 用 电脑 查询 时间 的 前提 是",
#     "我们 的确 有 方法 对齐 不同 地点 的 时钟",
#     "我们 所问 的 就是",
#     "这种 对钟 的 方法 究竟 是 什么",
#     "你 可能 会 想到",
#     "我们 先 在 北京 对 好 两个 时钟",
#     "再 把 其中 一个 拿到 上海 去 不 就行了 吗",
#     "可是   在 移动 的 过程 中",
#     "谁 也 不能 保证 时钟 的 走时 不 发生 任何 变化",
#     "当 它 移动 到 上海 时",
#     "未必 能 和 北京 的 钟 保持 同步",
#     "对于 这个 问题",
#     "庞加莱 提出 过 一种 猜想",
#     "他 认为   应该 通过 一种 约定",
#     "来 解决 时钟 的 对齐 问题",
#     "最 简单 的 约定 就是",
#     "光速 向 各个 方向 都 相同 而且 保持 不变",
#     "大家 看",
#     "假如 我们 想 对齐 北京 和 上海 的 时钟",
#     "可以 按照 这样 方法",
#     "找到 北京 和 上海 的 中点 M",
#     "然后 从 M 点 同时 向 北京 和 上海 发光",
#     "由于 约定 光 向 各个 方向 的 速度 都 一样",
#     "所以 两束 光 就 一定 能 同时 到达 北京 和 上海",
#     "当 北京 和 上海 接收 到 光时",
#     "就 把 当地 的 钟调 零",
#     "这样 它们 的 时钟 不 就 对齐 了 吗",
#     "庞加莱 真是 一位 伟大 的 哲学家",
#     "他 对 我们 司空见惯 的 \" 同时性 \"",
#     "提出 了 质疑",
#     "而且 还 敏锐 的 想到 了 通过 约定 光速 不变",
#     "就 能 对准 两个 不同 地点 的 时钟",
#     "得到 \" 同时性 \"",
#     "庞加莱 的 猜想",
#     "直接 启发 了 年轻 的 爱因斯坦",
#     "爱因斯坦 发展 了 庞加莱 的 理论",
#     "他 说",
#     "光速 在 任何 惯性 参考系 中 都 保持 不变",
#     "这 就是 光速 不变 假设",
#     "根据 这个 假设",
#     "绝对 的 时间 是 不 存在 的",
#     "爱因斯坦 在 本书 中",
#     "用 一个 闪电 劈 火车 的 例子",
#     "说明 了 这个 道理",
#     "我们 把 这个 例子 修改 一下",
#     "让 它 更 方便 理解",
#     "一辆 疾驰 的 高铁 中有 一节 餐车",
#     "在 餐车 的 头部 和 尾部",
#     "各有 一个 乘客 准备 用餐",
#     "侍者 站 在 车厢 正中间",
#     "点亮 了 一盏灯",
#     "这 盏灯 会 向 前方 和 后方 发出 光线",
#     "当 两名 乘客 看到 灯光 的 时候",
#     "就 开始 用餐",
#     "因为 两名 乘客 到 侍者 的 距离 是 一样 的",
#     "而光 的 传播速度 也 是 一样 的",
#     "所以 在 车厢 中 的 人 看来",
#     "两名 乘客 是 在 同一时间 用餐 的",
#     "可是 地面 上 的 道岔 工",
#     "会 如何 看待 这个 问题 呢",
#     "在 侍者 打开 灯 的 一瞬间",
#     "向前 和 向 后 的 灯光 速度 依然 是 相同 的",
#     "绝不会 因为 火车 在 运动",
#     "而 造成 某个 方向 的 光速 更 快",
#     "车尾 的 乘客 向前 运动",
#     "迎接 灯光   而 车头 的 乘客 也 是 向前 运动",
#     "却是 背离 灯光 而 去",
#     "显然   在 距离 相同 时",
#     "迎面而来 的 车尾 乘客 将会 更 早 接收 到 灯光",
#     "所以   在 地面 上 的 道岔 工 看来",
#     "车尾 的 乘客 先 开始 用餐",
#     "车头 的 乘客 后 开始 用餐",
#     "这就是说",
#     "火车 上 的 侍者 认为 同时 发生 的 事",
#     "地面 上 的 道岔 工却 认为 是 一先 一后 发生 的",
#     "同时 是 具有 相对性 的",
#     "在 一个 参考系 下 同时 发生 的 事",
#     "换 一个 参考系",
#     "就会 一先 一后 的 发生",
#     "所以   宇宙 中 不 存在 一个 统一 的 时间",
#     "永恒不变 的 流逝",
#     "紧跟着",
#     "爱因斯坦 指出   既然 时间 具有 相对性",
#     "那么 空间 尺寸 就 也 会 具有 相对性",
#     "像 欧几里得 几何 中 那种 刚性 的",
#     "绝对 不变 的 长度 是 不 存在 的",
#     "你 看   如果 你 要 测量 一列 火车 的 长度",
#     "你 就 需要 拿 一把 尺子 放在 火车 旁边",
#     "同时 读出 火车 头部 和 尾部 对齐 的 刻度",
#     "然后 把 它们 做差",
#     "就 得到 了 火车 的 长度",
#     "但是   除非 这 把 尺子 是 跟 火车 相对 静止",
#     "你 读 首尾 两个 刻度 的 时间 才 可以 不 一样",
#     "否则   假如 火车 在 地面 上 飞奔",
#     "你 必须 同时 读出 两个 刻度",
#     "才能 准确 测量 出 火车 的 长度",
#     "可是 我们 知道   同时 是 跟 参考系 有关 的",
#     "在 某个 参考系 上 看",
#     "同时 发生 的 事",
#     "换 一个 参考系",
#     "就 不是 同时 了",
#     "这样一来",
#     "火车 的 长度 就 也 跟 参考系 有关 了",
#     "爱因斯坦 说",
#     "麦克斯韦 方程组 计算 出 的 光速 是 恒定 的",
#     "我 又 假设 光速 在 所有 参考系 下 都 是 一样 的",
#     "所以   我们 当然 应该 认为 麦克斯韦 方程组",
#     "在 所有 惯性 参考系 下 都 是 成立 的",
#     "而 伽利略 早就 告诉 我们",
#     "力学 规律 在 不同 参考系 下 都 是 成立 的",
#     "既然如此",
#     "我们 就 干脆 假设",
#     "所有 的 物理 规律 在 所有 惯性 参考系 下",
#     "都 具有 相同 的 形式",
#     "这 就是 爱因斯坦 的 另 一个 基本 假设",
#     "相对性 原理",
#     "根据 爱因斯坦 相对性 原理",
#     "如果 在 空旷 的 宇宙 中",
#     "有 两个 宇航员 相互 远离",
#     "无论 你 用 任何 物理 实验",
#     "都 不能 确定 他们 究竟 谁 运动   谁 静止",
#     "因为 绝对 时空 原本 就 不 存在",
#     "你 说 谁 运动 都 可以",
#     "你 现在 在 家里",
#     "你 可以 说 相对 于 地球 自己 是 静止 的",
#     "你 也 可以 说 相对 于 太阳 是 运动 的",
#     "但是 你 不能 说 相对 于 绝对空间",
#     "自己 到底 是 静止 的 还是 运动 的",
#     "因为 压根 就 没有 绝对空间",
#     "根据 光速 不变 原理 和 相对性 原理",
#     "爱因斯坦 推导 出 了 不同 参考系 下",
#     "时间 和 空间 的 变化规律",
#     "这 就是 著名 的 洛伦兹 变换",
#     "之所以 叫 洛伦兹 变换",
#     "是因为 这个 规律 最早 是 洛伦兹 提出 的",
#     "他 为了 解释 迈 克耳孙 - 莫雷 实验",
#     "提出 物体 在 运动 的 方向 上 长度 会 收缩",
#     "而且 还 得出 了 正确 的 公式",
#     "只 可惜",
#     "洛伦兹 认为 的 收缩",
#     "是 物体 在 绝对空间 中 的 实际 收缩",
#     "他 甚至 还 带 着 学生 研究 在 收缩 过程 中",
#     "电荷 密度 的 变化 会 造成 什么 影响",
#     "但 我们 之后 就 会 看到",
#     "这种 收缩 并 不是 物体 在 时 空中 的 收缩",
#     "而 只是 因为 观察者 所在 的 时空 角度 不 一样",
#     "如果 我们 总结 一下",
#     "牛顿 时空观 的 问题 究竟 在 哪里 呢",
#     "它 在于",
#     "牛顿 假设 存在 一个 绝对 静止 的 空间",
#     "和 一个 永恒 流逝 的 时间",
#     "使用 力学 规律",
#     "我们 无法 找到 绝对 静止 的 空间",
#     "当然 也 无法 反驳 它 的 存在",
#     "有 了 电磁学 规律 之后",
#     "我们 能够 找到 绝对空间 了",
#     "但是 我们 却 发现 我们 的 实验 失败 了",
#     "于是   爱因斯坦 修改 了 牛顿 的 假设",
#     "他 认为   绝对 的 不是 时间 和 空间",
#     "而是 真空 中 的 光速",
#     "不管 在 什么 参考系 中",
#     "真空 中 的 光速 都 恒定 不变",
#     "无论是 力学 规律 还是 电磁学 规律 也 是 不变",
#     "这样 我们 就要 承认 时间 和 空间 都 和 运动 有关",
#     "都 是 变化 的",
#     "绝对 时空 并 不 存在",
#     "狭义 相对论 有 很多 有趣 的 结论",
#     "比如   在 地面 上 看",
#     "运动 的 火车 长度 会 收缩",
#     "如果 速度 接近 光速",
#     "长度 就 会 收缩 成 0",
#     "在 地面 上 看",
#     "运动 的 火车 里 的 时间 会 变慢",
#     "如果 火车 速度 接近 光速",
#     "时间 就 会 停滞",
#     "由于 运动 是 相对 的",
#     "火车 上 的 人 看 地面",
#     "也 会 有 长度 收缩 和 时间 变慢 的 现象",
#     "有 一部 著名 的 科普 书",
#     "《 物理 世界 奇遇记 》",
#     "主人公 汤 普金斯 先生 来到 了",
#     "一个 光速 非常 慢 的 小镇",
#     "他 发现 骑车 的 人 和 开动 的 汽车 长度 都 缩短 了",
#     "而 汤 普金斯 自己 骑车 的 时候",
#     "反而 发现 街旁 的 路 人 和 高楼 全都 跟着 变窄 了",
#     "当 我们 跑 起来",
#     "整个 宇宙 中 的 每 一个 星系",
#     "每 一个 星球   每 一个 生命",
#     "每 一个 原子 的 尺寸 都 发生 了 变化",
#     "而 当 我 停下 时",
#     "一切 又 都 恢复 了 原样",
#     "就 好像 什么 都 不曾 发生",
#     "而且",
#     "这 一切 的 变化 都 是 对于 我 这名 观察者 而言",
#     "对 另 一个 以 其他 速度 运动 的 观察者 来讲",
#     "宇宙 又 是 另一番 景象",
#     "于是   有 同学会 感觉 很 疑惑",
#     "我 一旦 运动 起来",
#     "整个 宇宙 的 时间 和 空间 都 会 发生变化",
#     "而 我 一 停下",
#     "时空 又 会 恢复 如初",
#     "难道 我 有 这么 大 的 能量",
#     "能 改变 宇宙 吗",
#     "关于 这个 问题",
#     "我会 在 下 一期 漫谈 相对论 中",
#     "为 大家 做 一个 简单 的 说明",
#     "关注 我",
#     "和 我 一起 读 爱因斯坦 的 名著",
#     "《 狭义 和 广义 相对论 浅 说 》"
#   ]
# }
# {
#   "video_id": "FtLj8WUcqow",
#   "captions": [
#     "各位 同学 大家 好   我 是 李永乐 老师",
#     "上 一回 咱们 讲 了 时间机器 之后   就 有 小朋友 问 我",
#     "时间机器 一旦 造成 了",
#     "那么 出现 了 这些 因果 悖论   怎么 去 理解 呢",
#     "今天 我们 就 来讲 一讲 关于 时间 旅行 的 因果 悖论",
#     "时间 旅行 是 一个 很 古老 的 话题",
#     "人们 特别 喜欢 用 这个 话题 来 制作 一些 科幻小说 或者 是 电影",
#     "那么 在 时间 旅行 的 时候 会 出现 很多 的 悖论",
#     "比如说 一个 典型 的 叫 祖父 悖论",
#     "也 有 叫 祖母 悖论",
#     "祖父 悖论 说 的 是 啥 呢",
#     "说 这个   有 一个 人",
#     "他生 了 一个 儿子",
#     "后来 这个 儿子 长大 了   长大 了 之后",
#     "就 又 生 了 一个 儿子",
#     "好   生完 了 之后   第一个 人 就 叫 祖父 了",
#     "第二个 人 叫 父亲   第三个 人 叫 儿子",
#     "但是 这 儿子 过得 非常 不 幸福",
#     "他 认为 自己 的 这个 悲剧 都 来源于 他 祖父",
#     "于是 他 想 回到 过去 把 他 祖父 杀 了",
#     "这样 自己 就 不会 出生 了   对 不 对",
#     "于是 他 就 回到 过去 把 他 祖父 给 杀 了",
#     "那么 现在 问题 来 了",
#     "这个 人 他 到底 能 不能 穿越时空 回到 过去",
#     "在 他 祖父 小 的 时候   把 他 祖父 杀掉 呢",
#     "如果说   他 可以 杀掉 的话   那 就是 祖父 死亡 了",
#     "祖父 如果 死亡 的话   那么 就 根本 不会 生出 父亲 来",
#     "如果 没有 父亲   自然 也 就 不会 有 这个 儿子",
#     "没有 儿子 的话   儿子 也 就 不会 穿越时空 回到 过去 把 祖父 杀掉",
#     "所以   祖父 就 不会 死   对 吧",
#     "那么 反过来说   如果 祖父 没死 呢",
#     "如果 祖父 是 活着 的   他 确实 是 可以 生出 爸爸 来",
#     "而 爸爸 也 确实 是 可以 生出 儿子 来",
#     "这个 儿子 如果 有 时间机器   他 就 可以 回到 过去 把 他 祖父 杀 了",
#     "所以 A 就 会 死   这样一来 就 出现 了 悖论   对 不 对",
#     "那么 对于 这个 悖论 怎么 去 解释",
#     "当然 我们 可以 说 时间机器 根本 不 存在",
#     "所以 这 悖论 就 无所谓 了   对 吧",
#     "那么 假设 时间机器 是 存在 的",
#     "我们 能 不能 去 理解 这个 祖父 悖论 呢",
#     "我们 对 它 其实 还是 有 很多 的 解释 的",
#     "主流 的 解释 我们 可以 把 它 大概 分成 这么 三种",
#     "咱们 说 一下",
#     "第一种 解释   叫做 香蕉皮 假说",
#     "这个 什么 叫 香蕉皮 假说 呢",
#     "这个 假说 挺好玩 的",
#     "香蕉皮 假说 的 意思 是 说",
#     "你 看   假如 这个 C 他 穿越 到 过去 了",
#     "穿越 到 过去 之后   他 说 我 现在 要 杀死 祖父",
#     "我 现在 要 杀死 我 的 祖父   拿 把 枪 去 杀 祖父 去 了",
#     "结果 他 看到 祖父 那 一瞬间 一定 会 有 一些 事 阻止 他",
#     "比如说 地下 有个 香蕉皮",
#     "他 在 开枪 一瞬间 香蕉皮 就 把 他 滑倒 了",
#     "于是 这个 子弹 打飞 了   祖父 活着   对 不 对",
#     "或者 出现 了 一些 其他 的 事",
#     "比如 他杀 了 一个 人   然后 回到未来 了",
#     "回到未来 之后   发现 祖父 怎么 还 活着",
#     "他杀 错 了   他 不是 亲生 的   对 吧",
#     "总而言之 有 各种各样 的 原因   他 最后 还是 活着",
#     "那 这 就是 所谓 的 香蕉皮 假说",
#     "香蕉皮 假说 大家 可以 回去 看 一部 电影",
#     "叫做 《 时间机器 》",
#     "《 时间机器 》 这部 电影 实际上 就是",
#     "根据 这个 威尔斯 的 同名 小说 改编 的",
#     "02 年 的 时候 上映 的 一部 电影",
#     "就 有 一个 男人 他 想 回到 过去   去 拯救 他 被 人 枪杀 的 女友",
#     "结果 发现 无论 他 如何 努力",
#     "他 都 没有 办法 改变 过去   是 吧   就 这么 一个 假说",
#     "不过 香蕉皮 假说 还是 比较 粗糙 的",
#     "人们 针对 这个 假说 又 提出 了 一个 更加 详细 的 说法",
#     "这 就 叫 诺 维科夫 自洽 原则",
#     "诺 维科夫 自洽 原则",
#     "诺 维科夫 是 前 苏联 的 这个 科学家",
#     "他 针对 这个 时空旅行 的 这个 问题",
#     "提出 了 一个 诺 维科夫 自洽 原则",
#     "这个 原则 说 的 是 什么 呢",
#     "他 说 这个 世界 发展 是 概率 性 的   就 像 量子力学 一样",
#     "它 每 一种 可能 都 是 存在 的   只不过 概率 大小 而已   对 吧",
#     "于是 那么 有 一些 情况 可能 是 违背 因果律 的",
#     "在 因果 矛盾 的 事件",
#     "这样 的 历史 事件 出现 的 概率 是 零",
#     "出现 的 概率 是 零",
#     "有 的 概率 大   有 的 概率 小",
#     "而 因果 矛盾 的 事件 出现 的 概率 为 零",
#     "那 如果 有 了 这个 原则 的话",
#     "那 有些 事 根本 就 不会 出现",
#     "比如说 如果 有 一个 小孩 要 回去 杀 他 祖父 的话",
#     "那 祖父 根本 就 不会 把 这个 人生 出来",
#     "为什么   因为 它 违背 了 因果律",
#     "所以 这些 事 根本 就 不会 发生",
#     "有人 说 那 万一 我 有 个 小孩 突然 之间 就 犯病 了",
#     "他 就 回去 杀 他 祖父   不行 吗",
#     "这诺 维科夫 就 说 我们 这样 吧",
#     "我们 把 它 变成 一个 更加 简单 的 模型",
#     "我们 不 考虑 人   我们 考虑 小球",
#     "比如说 这里 有 一个 白洞   这里 有 一个 黑洞",
#     "而 白洞 和 黑洞   又 组成 了 一个 时空 隧道",
#     "一个 物体 从 黑洞 进去   会 从 白洞 出来",
#     "而且 出来 的 时候 时间 更 早 一些",
#     "这个 时候 有 一个 小球 A",
#     "这个 小球 A 它 朝着 黑洞 进去 了",
#     "进去 了 之后   它 又 从 白洞 里 出来 了",
#     "而且 从白洞 出来 的 时间 比 进去 的 时间 还要 早 一些",
#     "出来 的 时候 它 又 正好 朝着 自己 撞 过去 了",
#     "结果 一撞 出现 了 什么 效果 呢",
#     "效果 就是 它 撞 了 自己   然后   偏向 了",
#     "而 自己 在 进 黑洞 之前 就 被 撞 了",
#     "于是 它 的 方向 就 发生 了 改变",
#     "它 就 往 这 走   它 就 进不了 黑洞 了",
#     "这 实际上 就 和 这个 祖父 悖论 是 一样 的 意思",
#     "你 看   如果 你 能 进 黑洞   你 就 能 撞 自己",
#     "你 能 撞 自己 的话   你 就 进不了 黑洞",
#     "如果 你 进不了 黑洞   你 就 不会 撞 自己",
#     "那 你 就 能 进 黑洞",
#     "对 吧   这 是不是 就 矛盾 了",
#     "他 说 这种 情况 是 不会 出现 的",
#     "因为 它 违背 了 因果律   所以 概率 是 零",
#     "那有 可能 出现 什么 情况 呢",
#     "有 可能 出现 这种 情况",
#     "还是 一个 白洞 一个 黑洞",
#     "说 这个 A 球   它 本来 是 朝着 黑洞 进去",
#     "朝着 黑洞 这么 进去 了   对 吧   本来 是 想 这么 进去",
#     "结果   它 又 从 白洞 里 用 一个 更 早 的 时间 它 出来 了",
#     "出来 的 时候 撞 自己   然后 它 偏 了",
#     "自己 被 撞 了 之后   它 没有 完全 偏离 这个 方向",
#     "它 稍微 的 往 这边 挪 了 一点",
#     "但是 它 还是 进去 了   那 这个 就是 合理 的",
#     "所以 这种 情况 概率 就 不是 零",
#     "当然 除了 这种 情况 以外 还有 很 多种 可能",
#     "比如说 再举 一个 例子",
#     "这是 白洞   这是 黑洞",
#     "本来 这个 小球 A   它 是 直 着 往上走 的",
#     "它 压根 就 没想 进白洞 还是 进 黑洞",
#     "但是 它 走 到 白洞 黑洞 之间 的 时候",
#     "被 一个 玩意 给 撞 了",
#     "撞 完 了 之后   它 就 进 了 黑洞 了",
#     "进完 了 黑洞 之后   它 又 从 白洞 里 出来 了",
#     "从白洞 里 出来 还 没 反应 过来   结果 发现自己 撞 了 一个 物体",
#     "撞 了 谁   就 撞 了 原来 的 自己   对 吧",
#     "然后 撞 完 了   它 又 往前走 了",
#     "说 这种 情况 也 是 有 可能 出现 的",
#     "因为 它 不 矛盾",
#     "只要 是 不 矛盾 的 就是 有 可能 出现 的",
#     "而 所有 矛盾 的 它 出现 的 概率 都 是 零",
#     "这 就是 诺 维科夫 自洽 原则",
#     "从诺 维科夫 自洽 原则 我们 可以 看 出来",
#     "你 想 改变 历史 这事 是 做 不到 的",
#     "因为 它会 违背 因果律   对 吧",
#     "如果 你 想 回到 过去 阻止 一场 火灾 的 发生",
#     "那么 很 有 可能 你 会 发现 最后 是 你 引起 了 这场 火灾",
#     "在 这里 也 给 大家 推荐 一部 电影",
#     "名字 叫 《 十二 猴子 》",
#     "这部 电影 讲 的 是 一个 关于 病毒 的 一个 这个 科幻电影",
#     "还是 很 不错 的   大家 可以 看一看",
#     "除了 这 两种 说法 以外",
#     "我们 再 来看 一个 更加 离奇 的 说法",
#     "叫 艾 弗雷 特他 的 一个 说法",
#     "他 说 呢",
#     "我们 可以 通过 多重 宇宙 去 避免 这个 悖论",
#     "什么 叫 多重 宇宙 呢",
#     "以前 我们 讲 薛定谔 的 猫 的 时候 其实 就 提到 过 这个 概念",
#     "因为 量子 世界 是 概率 性 的",
#     "那么 有人 认为",
#     "这个 量子 世界   概率 性 的 世界",
#     "并 不是 进行 坍塌   而是 进行 分裂",
#     "比如说 有 一个 人   他 拿 了 一个 盒子",
#     "盒子 里边 装 了 一大堆 物体",
#     "然后 他 就 把 这 物体 拿 出来 看看 是 什么",
#     "那么 他 有 可能 拿出 一个 红球 来",
#     "结果 一看   这个 球是 红 的",
#     "也 有 可能   拿出 一个 蓝球 来",
#     "一看   这个 球是 蓝色 的",
#     "这个 时候 他 拿出 不同 的 球",
#     "其实 就 表示 这 两个 宇宙 进行 分裂 了",
#     "有 一个 宇宙 中 拿 出来 就是 红球",
#     "有 一个 宇宙 中 拿 出来 就是 蓝球",
#     "然后 他 接着 拿",
#     "结果 上面 这个 人 也 有 可能 再 拿出 一个 三角形 来",
#     "也 有 可能 拿出 一个 方块 来   这 就 宇宙 又 分裂 了",
#     "底下 这个 人 也 是 拿出 一个 球来",
#     "或者 是 拿出 一个 六边形 来   这 宇宙 又 分裂 了",
#     "如此这般   宇宙 是 持续 不断 进行 分裂 的",
#     "那么 如果 我们 有 了 多重 宇宙 这种 观点 的话 呢",
#     "这个 祖父 悖论 就 很 好 解释 了   我们 看 怎么 解释",
#     "就是 有 这么 两个 宇宙",
#     "第一个 宇宙   有 一个 爷爷",
#     "有 一个 父亲   还有 一个 儿子",
#     "这个 儿子 有 一天   犯病 了   说 我 非要 把 我 爷爷 杀 了",
#     "于是 他 就 回到 过去 了",
#     "但 他 回到 的 过去 并 不是 它 自己 这个 过去",
#     "而是 另外 一个 平行 宇宙 的 过去",
#     "平行 宇宙 里边 也 有 一个 他 爷爷",
#     "于是 他 就 过去 把 他 爷爷 杀 了",
#     "把 他 爷爷 杀 了 之后   自然 在 第二个 宇宙 里边",
#     "也 就 没有 爸爸   也 就 没有 他 了   对 不 对",
#     "但是 当 这个 人 回到 自己 的 世界 里边 的 时候",
#     "他会 发现 他 爷爷 还 在   为什么 呢",
#     "因为 他 改变 的 不是 自己 的 过去",
#     "而是 另外 一个 宇宙 的 过去",
#     "你 这么 去 理解 它 是不是 就 可以 解释 了",
#     "好   在 时间机器 这个 问题 上",
#     "其实 还有 一个 人物 我们 要 提 一下 就是 霍金",
#     "霍金 当然 说 是 特别 喜欢 这些 新奇 的 玩意儿",
#     "但是 他 对于 时间机器 的 看法 是 什么 呢",
#     "他 在 92 年 的 时候 就 提出 了 一种 假说",
#     "叫做 时序 保护 假说",
#     "时序 保护 的 意思 是 说",
#     "这个 大自然 是 厌恶 时间机器 的",
#     "或者说 时间机器 是 不 存在 的",
#     "霍金 说 时间机器 为什么 不 存在 呢",
#     "有 很 多种 证据",
#     "比如说 时间机器 如果 存在 宇宙 会 被 炸掉",
#     "说 为什么 宇宙 会 被 炸掉 呢",
#     "假如 这里 有 一个 白洞   这里 有 一个 黑洞",
#     "我们 构筑 了 一个 虫 洞   然后 造出 了 时间机器",
#     "白洞 的 时间 比 这个 黑洞 时间 更 早",
#     "那么 黑洞 和 白洞 之间 有 真空   真空 就 有 一个 说法",
#     "叫 真空 涨落",
#     "这个 真空 涨落 我们 在 讲 不确定性 原理 的 时候 会 说 到",
#     "真空 涨落 就是 真空 中 会 无中生有 的 产生 电磁波",
#     "那 你 如果 无中生有 产生 电磁波 了",
#     "这个 电磁波 穿 到 了 黑洞 里边",
#     "它 就 会 从 白洞 里 出来",
#     "从白洞 里 出来 了 之后 又 会 进到 黑洞 里   对 吧",
#     "它 就 又 从 白洞 里 出来 的   而且 时间 更 早",
#     "它 就 又 进到 黑洞 里 了",
#     "如此这般   这 黑洞 和 白洞 之间 电磁波 就 会 无限 的 扩大",
#     "一瞬 之间 这个 黑洞 白洞 就 炸掉 了",
#     "不仅如此   整个 宇宙 也 都 炸掉 了",
#     "所以 说   你 宇宙 为什么 没有 炸掉   就 因为 没有 时间机器",
#     "有 时间机器 宇宙 就 没 了   对 吧",
#     "这 是 他 的 一个 说法   为了 证实 自己 的 说法 呢",
#     "他 在 2009 年 的 时候",
#     "6 月 28 日   他 举办 了 一个 宴会",
#     "结果   发现 这个 宴会 一个 人 都 没有 来",
#     "就 他 自己 摆着 香槟   摆着 小吃   没有 任何人 来",
#     "说 霍金 举办 的 宴会 为什么 没有 人来 呢",
#     "因为 它 是 一个 面向未来 旅行者 的 宴会",
#     "他 是 在 宴会 结束 之后 才 向 全世界 发布 了 这个 通知",
#     "他 说 我 今天 我要 举办 一个 宴会   但 这个 宴会 已经 结束 了",
#     "如果 你们 要是 有 时空 机器 的话",
#     "希望 你们 能 利用 时空 机器 回到 这个 日子   对 吧",
#     "到 我 家里 来   然后 我们 组织 这么 一个 宴会",
#     "那 没有 人来   说明 什么",
#     "说明 时间机器 是 不 存在 的",
#     "霍金 说   说 如果 时间机器 是 存在 的",
#     "我们 为什么 看不到 时空旅行 者 呢",
#     "为什么 看不见 未来 的 人 呢",
#     "那 未来 如果 有 时间机器",
#     "我们 为什么 看不见 他们 呢   是 吧",
#     "所以 因为 我们 看不见 时间机器",
#     "说明 未来 的 人 他 也 没有 办法 穿越",
#     "因此 时间机器 是 不 存在 的",
#     "当然 了   针对 霍金 这种 说法 也 有 很 多种 反驳 的 意见",
#     "比如说 有人 就 说 了   说 不是 未来 人 不 在",
#     "未来 人 就 在 我们 身边",
#     "他们 都 伪装 你 知道 吗",
#     "他们 都 伪装 起来   伪装 起来 让 你 不 知道",
#     "实际上 就 在 我们 身边",
#     "这是 一种 说法",
#     "还有 一种 说法",
#     "就是说 只有 在 时间机器 造 出 之后",
#     "时间机器 你 现在 没 造出来   所以 别人 也 来 不了",
#     "只有 你 时间机器 造 出 之后 的 时间   才 是 可 访问 的",
#     "举个 例子   比如说 你 在 3000 年 你 造出 了 时间机器",
#     "那好   你 就 可以 从 3000 年 穿越 到 4000 年",
#     "反过来 5000 年 的 人 也 可以 穿越 回 3000 年",
#     "你 就 可以 跟 未来 人 相见 了",
#     "那 为什么 我 现在 看不见 未来 的 人 呢",
#     "因为 我们 还 没造 出 时间机器 呢",
#     "什么 时候 造 出 时间机器",
#     "你 就 看到 未来 的 人 就 噗 噗 噗 全都 来 了   对 吧",
#     "当然 这 其实 也 有 问题",
#     "如果 我们 有 一天 真的 造出 了 时间机器",
#     "那 那个 宇宙 在 那 一瞬间 就 会 毁掉",
#     "为什么 呢",
#     "谁 不想 去 看一看 时间机器 形成 之初 的 样子",
#     "于是 所有 未来 的 人 都 会 跑 到 那个 地方",
#     "整个 宇宙 就 被 人 肉酱 了   挤爆 了   是 吧   就 这样",
#     "所以 这个 时间机器 其实 还是 挺好玩 的 一个 话题",
#     "大家 如果 喜欢 我 的 视频",
#     "可以 在 西瓜 视频 和 YouTube 帐号 李永乐 老师 里 关注 我"
#   ]
# }
# {
#   "video_id": "ii1fTxhD_D0",
#   "captions": [
#     "各位 同学   大家 好   我 是 李永乐 老师",
#     "因为 新冠 肺炎 在 全世界 蔓延",
#     "造成 全球 需求 不振   石油价格 一路 狂泻",
#     "在 美国 时间 4 月 20 号 的 时候",
#     "更是 出现 了 WTI 原油期货 价格",
#     "跌到 了 - 37.63 美元",
#     "意思 是 说   你 买 油 非但 不要 钱",
#     "每 一桶 还 白送 你 37 块 6 毛 3 美元",
#     "有 小朋友 就 问 我 说 这 是 怎么回事 呢",
#     "为什么 买油 还 可以 白送 钱 呢",
#     "更为 神奇 的 是   很多 国内 投资者",
#     "因为 投资 了 一款 叫做 原油 宝 的 产品",
#     "账户 里 不光 钱 清零 了   还 倒 欠 银行 一笔 钱",
#     "这 又 是 怎么回事 呢",
#     "今天 就 来 给 大家 普及 一下 关于 期货 的 知识",
#     "期货   我们 在历史上 是从 远期 合约 开始 的",
#     "其实 远期 合约",
#     "在历史上 很久很久 以前 就 已经 有 了",
#     "那么 这种 合约 它 是 区别 于 现货 的",
#     "什么 叫 现货 呢",
#     "就是 一手交钱 一手交货",
#     "我 想 买 一个 东西",
#     "我 把 钱 给 人家   人家 把 东西 给 我   这 就 叫 现货",
#     "而 期货 的 意思 就是说 我 把 钱 或者 一部分 钱 给 你",
#     "但是 这个 东西 还 没有 生产 出来",
#     "再过 了 一段时间 之后 你 再 把 东西 给 我",
#     "我们 可以 打 一个 比方",
#     "比如说 我们 现在 买 期房 很多 时候 就 这样",
#     "先 付钱   过 了 一段时间 之后 房子 才 会 给 我",
#     "那么 这个 远期 合约",
#     "其实 最早   古希腊 时代 可能 就 有",
#     "但是 比较 正规 的 是 在 荷兰",
#     "大家 还 记得 荷兰 有 一次 叫 郁金香 狂热 吗",
#     "那么 在 荷兰 郁金香 狂热 的 时候",
#     "很多 郁金香 就 被 卖光 了",
#     "那么 别人 想 买 郁金香 买不到   怎么办",
#     "跟 花农 说   我要 预订 明年 的 郁金香",
#     "我 先 把 钱 给 你   明年 的 时候 你 把 郁金香 给 我",
#     "咱们 签 一份 合约   这个 就 叫 远期 合约",
#     "除了 荷兰 郁金香 以外",
#     "在 亚洲 日本   有 江户 幕府 的 时代",
#     "江户 幕府 的 时代",
#     "有 一种 资源 就是 稻米   特别 重要",
#     "一旦 要 打仗 那 就 得 吃 很多很多 的 米   对 吧",
#     "将军 就要 买米",
#     "但是 将军 不 知道 明年 这个 米价",
#     "会 上涨   还是 会 下跌",
#     "于是 将军 就 跟 这个 农民 说",
#     "说 我 现在 先 把 钱 付给 你",
#     "你 就 按照 这个 价格 明年 给 我 稻米   对 吧",
#     "所以 你 不用 管 明年 到底 是 涨价 还是 跌价",
#     "咱们 必须 得 按照 这个 价格 来",
#     "那么 这个 我们 就 称之为 远期 合约",
#     "如果 我们 具体 地 把 这个 画 一个 图",
#     "远期 合约 有 一个 交易 对手   交易 对手",
#     "这个 交易 对手",
#     "他们 两个 在 某 一个 时间 先签 一份 合约",
#     "比如说 右边 的 这个 人 是 幕府将军",
#     "左边 的 这个 是 农民",
#     "这 幕府将军 就 跟 农民 说 了   说明 年 可能 要 打仗",
#     "所以 说 我 要 先 给 你 订购 粮食",
#     "于是 咱们 来 签 一个 合约",
#     "我 把 一部分 钱 给 你   然后 你 就 把 一份 合约 给 我",
#     "明年 我 就 拿 着 这个 合约",
#     "我 找 你 要 粮食   对 不 对",
#     "好 了   到 了 第二年 了",
#     "这个 将军 拿 这个 合约 就 给 了 这个 农民 了",
#     "然后 这个 农民 就 把 合约 里 所 规定 的 稻米",
#     "再 给 这个 将军   对 吧",
#     "整个 这个 过程 它 就 完成 了",
#     "这种 过程 我们 就 称之为 远期 合约",
#     "那么 它 最 重要 的 作用 是 什么 呢",
#     "其实 就是 套期 保值",
#     "套期 保值   什么 叫 套期 保值 呢",
#     "我们 刚才 说 过   这个 商品 的 价格 是 在 波动 的",
#     "比如说 这个 将军 和 农民 签订 条约 的 时候",
#     "他们 两个 会 按照 某 一个 价格 去 计算",
#     "但是 明年 的 时候",
#     "这个 稻米 的 价格 不 一定 是 这个 价格",
#     "也许 稻米 价格 就 上涨 了",
#     "如果 稻米 价格 要是 上涨 了 的话",
#     "那么 对 农民 自然 是 有益 的",
#     "他 卖 了 可以 卖 更 多 的 钱",
#     "但是 对于 将军 来讲 他 买 米 就要 花 很多 钱",
#     "所以 他 害怕 稻米 价格上涨",
#     "他 就 提前 锁定 了 稻米 的 价格",
#     "反过来说   如果 稻米 价格 要是 下跌 了 呢",
#     "稻米 价格 下跌",
#     "对 将军 来讲 当然 是 有利 的   对 不 对",
#     "对 农民 来讲",
#     "他 种田 了 之后 卖 不到 很多 钱   他 就 会 亏本",
#     "所以 他 也 害怕 价格 下跌",
#     "因此 他 也 需要 提前 锁定",
#     "那么 既然 双方 都 有 这个 需求",
#     "咱们 不妨 两个 人 就 订 一份 合约",
#     "在 明年 的 时候 以 一个 约定 的 价格 来 交易",
#     "谁 也 别 吃亏   谁 也 别 占便宜",
#     "这个 就是 所谓 的 套期 保值 的 这样 一个 作用",
#     "我们   因为 价格 是 在 波动 的",
#     "但是 我 通过 这个 合约 的 方法",
#     "我 就 可以 锁定 这个 价格   锁定 买卖 的 这个 价格",
#     "那么 对 有 一些 生产 的 企业",
#     "其实 这个 作用 还是 很 明显 的",
#     "但是 远期 合约 也 有 它 的 问题",
#     "我们 说 一下 它 的 问题 在 哪",
#     "它 的 问题   第一个 问题",
#     "就是 远期 合约 很 容易 出现 毁约 的 情况",
#     "就 比如说 这个 将军 要 跟 农民 买 稻米",
#     "他 可能 不会 把 所有 的 钱 都 给 农民",
#     "他 可能 给 一部分 定金",
#     "比如说 将军 说 了",
#     "我 先 给 你 100 两 银子 作为 定金",
#     "明年 你 给 我 100 担 稻米",
#     "我 再 把 尾款 付给 你",
#     "但是 到 了 第二年 这个 100 担 稻米",
#     "它 涨价 涨到 300 两 银子 了",
#     "这 农民 一 算 如果 我 要是 毁约",
#     "我 不 卖 给 这个 将军 的话 那 我 赚 的 更 多",
#     "于是 农民 就 偷偷地 把 这 原来 的 定金 退 给 了 将军",
#     "然后 带 着 粮食 跑 到 别的 地方 去 卖   对 不 对",
#     "那 如果 出现 这种 情况 下 将军 他 就 吃亏 了",
#     "那 反过来说 将军 有 可能 毁约",
#     "比如说 第二年 的 时候 稻米 价格下降 很多",
#     "将军 一 算   我 就算 我 这个 定金 不要 了",
#     "我 重新 去 买 我 还是 赚钱   对 不 对",
#     "所以 跟 农民 就 说 了",
#     "说 我 给 你 的 定金 我 不要 了",
#     "我 从 别的 地方 我 重新 去 买 米",
#     "所以 这 就是 第一个 问题   有 可能 会 造成 毁约",
#     "那么 除此之外",
#     "就是 这个 商品 的 质量 它 也 没有 办法 保证   对 吧",
#     "你 进行 检验 的 时候 你 得 双方 进行 检查",
#     "每 一次 检查 都 非常 费劲",
#     "再 比如说   交易 也 是 不 方便 的",
#     "什么 叫 交易 不 方便 呢",
#     "就 比如说 吧",
#     "这个 农民 签 了 约 之后 突然 之间 他 生病 了",
#     "他 没法 种地 了",
#     "所以 他 就 跟 将军 说",
#     "说 我 这个 不能 再 种地 了",
#     "这个 合约 我 没法 再 履行 了",
#     "我能 不能 把 这个 合约 我 卖 给 另外 一个 农民",
#     "让 他 跟 你 继续 去 履行 呢",
#     "那 这个 时候 就 存在 一点 问题",
#     "将军 有 可能 会 不 同意",
#     "说 你 生病 了 你 也 必须 得 给 我 下地干活   对 吧",
#     "所以 这样 就 出现 了 一个 交易 不便 的 情况",
#     "那么 因为 有 了 这些 问题",
#     "人们 希望 能够 把 这种 远期 合约 变得 更加 标准化",
#     "那 就是 现在 我们 所谓 的 叫做 标准 期货 合约",
#     "标准 期货 合约 它 跟 这个 远期 合约 相比",
#     "就 有 很多 的 好处 了",
#     "标准 期货 合约 最早 是 在 1865 年 的 时候",
#     "1865 年 在 芝加哥",
#     "芝加哥 有 两家 期货 交易所",
#     "一家 叫 芝加哥 期货 交易所",
#     "一家 叫 芝加哥商品交易所",
#     "后来 它们 两个 合并 了",
#     "在 芝加哥 有 这家 这个 期货 交易所",
#     "这个 期货 交易所",
#     "他 就 创立 了 第一份 这个 标准 期货 合约",
#     "标准 期货 合约",
#     "现在 的 这个 合约 模型 也 是 以 它 当年 为 蓝本 的",
#     "就是 在 这个 标准 期货 合约 里面",
#     "它 规定 了 什么 呢",
#     "首先 规定 了 商品 的 质量",
#     "你 这个 商品 要 达到 一个 什么样 的 级别",
#     "我 规定 的 标准 是 非常 清楚 的",
#     "现在 来讲 就是",
#     "只有 某些 厂家 生产 的 商品",
#     "才 可以 进入 这个 市场",
#     "其他 厂家 都 不行   就 这 几个 厂家 才行",
#     "还有 就是 数量",
#     "你 是 1000 担 稻米   还是 100 两 黄金",
#     "还是 什么",
#     "然后 还有 就是 交割 的 时间",
#     "你 这个 每 一个 商品 什么 时候 交割",
#     "交割 的 地点   你 在 哪 交割",
#     "交割 的 方式   怎么 交割",
#     "都 说 得 非常 清楚",
#     "还有 一个 就是 这个 合约 我 是 可以 交易 的",
#     "我 是 可以 在 场内 交易 的",
#     "什么 叫 场内 交易 呢",
#     "就是 拿到 交易所 里面 去",
#     "假如 你 有 一份 合约",
#     "后来 你 说 我 这 合约 没法 履行",
#     "我 把 它 卖掉   这是 可以 的",
#     "拿到 厂里 边去   拿到 这个 交易所 里面 去",
#     "我们 就 可以 帮 你 把 它 卖掉",
#     "那么 有 了 这些 规定 之后",
#     "这个 合约 交易 起来 就 非常 便捷 了",
#     "我们 举 一个 例子   比如说 有 一种 商品",
#     "这个 商品 的 合约 叫 WTI   叫 轻质 原油期货",
#     "原油期货",
#     "这个 也 就是 这 一次 原油 宝 的 那个 标的",
#     "造成 了 很多 人 倒 欠 银行 钱 的 这个 东西",
#     "WTI 原油期货   这个 叫 什么 意思 呢",
#     "它 其实 就是 一份 合同",
#     "你 要是 买 了 这份 合同 它 上面 会 这么 写 着",
#     "说 现在 这份 合同规定",
#     "有 轻质 原油   轻质 低硫 原油",
#     "某 一种 原油 的 这个 型号   轻质 低硫 原油",
#     "多少 桶 呢",
#     "1000 桶   这 是 它 的 数量",
#     "那么 你 有 了 这份 合约 之后",
#     "你 就 可以 以 某 一个 价格 去 拿到 这个 原油 了",
#     "那么 这个 时间 是 在 每月 的   不太 一定",
#     "比如说 20 ~ 25 日   你 可以 去 提 这个 原油",
#     "提 原油 的 地点 在 哪 呢",
#     "在 美国 一个 叫做 库欣 的 地方",
#     "里边 有 很多 的 储油罐",
#     "好   你 看   它 这 里面 就 规定 了 这个 原油 的 质量",
#     "轻质 低硫 原油   对 吧",
#     "数量 就是 1000 桶",
#     "交货 的 时间 地点 都 规定 了",
#     "如果说 你 不 想要 了",
#     "你 还 可以 拿到 场 里边 去 交易",
#     "拿到 交易所 里面 卖掉",
#     "那么 唯一 没有 确定 的 是 什么",
#     "是 这份 合约 的 价格",
#     "这个 价格 是 在 开仓 的 时候   交易 双方 进行 确定",
#     "就 好像 当年 的 将军 和 农民",
#     "他们 之间 可以 拿 着 这个 标准 合约",
#     "然后 商量 这份 合约 到底 值 多少 钱 呢   对 吧",
#     "咱们 商量 好 的 一个 价格   我们 就 可以 立 一个 约",
#     "然后 到时候 我们 进行 交割 就行了",
#     "但是 因为 它 进行 交易 的 时候 非常 方便",
#     "所以 很多 人 发现 其实 我 并不需要 最后 去 买 原油",
#     "我 只 需要 在 这个 买卖 合约 的 过程 中",
#     "我 不 就 可以 获利 了 吗",
#     "那么 这种 方式   我们 就 称之为 投机 交易",
#     "我们 来说 一下 期货 的 投机",
#     "期货 的 投机   我们 来说 一下 期货 的 投机",
#     "我们 知道 在 股票市场 上 有 一些 投机者",
#     "但是 也 有 一些 投资者   投资者 的 意思 就是",
#     "我 买 这 股票   我 不是 指望 着 低买高卖 赚 差价",
#     "我 就是 想 跟着 公司 一起 成长",
#     "毕竟 是 有 这样 一部分 人 的",
#     "但是 在 期货市场 上   绝大多数 的 人 都 是 投机者",
#     "这 是因为 期货市场 有 它 自己 的 特点",
#     "它 不能 像 股票 那个 样子 长期 持有",
#     "它 持有 成本 非常 高",
#     "所以 大家 基本上 都 是 通过 这个 买卖",
#     "就是 想 赚 一票 就 走",
#     "通过 这个 方法 来 获利",
#     "首先 像 股票 一样   期货 也 有 一个 价格",
#     "我们 说 一下 它 的 价格 怎么 算",
#     "这个 期货 合约 的 价格   这个 合约 的 价格",
#     "合约 的 价格 等于 什么 呢",
#     "它 等于 一个 单价   再 乘以 一个 合约 的 规模",
#     "规模 其实 就是 数量",
#     "我们 举个 例子",
#     "比如说 这个 WTI 这个 原油",
#     "那 它 这 一份 合约 值 多少 钱 呢",
#     "首先 咱们 先 商量 一个 单价",
#     "你 觉得 这个 20 美元 可以 买 一桶 油",
#     "我 觉得 也 还 可以   那 咱们 就 立约",
#     "于是 单价   比如说 是 20 美元",
#     "然后 就是 合约 规模",
#     "那 合约 规模 是 一份 1000 桶   对 不 对",
#     "所以 乘以 1000",
#     "最后 这么 一 算   就是 2 万美元",
#     "好   那么 这 一份 合约 就值 2 万美元",
#     "当然   这 2 万美元 并 不是 我 打 给 你",
#     "或者 是 你 打 给 我 的",
#     "它 跟 股票交易 还 不 太 一样",
#     "它 不是 你 打 给 我   我 打 给 你",
#     "咱们 的 意思 是   在 某 一个 特定 的 时间",
#     "比如 每月 20 到 25 号",
#     "我们 可以 以 2 万美元 的 价格",
#     "去 交割 1000 桶 原油",
#     "是 这个 意思   对 吧",
#     "而且 这个 买卖 的 过程   其实 我们 称之为 开仓",
#     "称之为 开仓",
#     "来说 一下 这个 开仓 的   还有 平仓 的 意思",
#     "这是 两个 人   这 两个 人",
#     "一个 人 他 是 想 买 原油 的",
#     "另外 一个 人 他 是 想 卖 原油 的   是 吧",
#     "就 相当于 刚才 的 这个 农民   还有 这个 将军",
#     "那么 这个 想 买 原油 的 这 一方",
#     "想 买 原油 的 这 一方   我们 就 称之为 多方",
#     "而 想 卖 原油 的 这 一方   我们 就 称之为 空方",
#     "然后 有 一天 他们 就 开 了 一个 单   开 了 一个 单",
#     "首先 他们 俩立 了 一个 约",
#     "这个 空方 把 一个 合约 卖 给 了 多方",
#     "这个 时候 我们 就 叫 开仓",
#     "在 开仓 的 过程 之中 有 一个 价格 叫 P1",
#     "这个 P1 就是 什么 呀",
#     "就是 这 2 万美元   对 不 对",
#     "好 了",
#     "现在 多方 按说 是 已经 拿到 了 1000 桶 油 了",
#     "他们 约定 是 以 2 万美元 的 价格",
#     "来 买 这 1000 桶 油   对 不 对",
#     "只不过 还 没有 交货 而已",
#     "而 空方 是 已经 卖 再 出 了 1000 桶 油",
#     "他 约定 价格 是 2 万美元",
#     "但 问题 是 空方 他 不 一定 有 原油",
#     "到 那个 时候 他 也 未必 能交 的 了 货",
#     "怎么办   没有 关系   等 过 一段时间 之后",
#     "他们 俩 都 会 平仓   都 会 平仓",
#     "所谓 平仓 的 意思 就是",
#     "这份 合约 又 从 这个 多方 还给 空方 了",
#     "这个 时候 再有 一个 价格 就是 P2",
#     "但是 P1 和 P2 它 是 随着 价格",
#     "这个 市场 在 波动 的   对 吧",
#     "好   咱们 来 思考 一下",
#     "假如 这个 价格上涨 了   假如 价格上涨 了",
#     "也就是说 这个 原油 原来 的 价格",
#     "低于 后来 的 价格   后来 价格 高",
#     "那么 对 谁 有利 呢",
#     "后来 价格 高 的 意思 就是 我 这个 多方",
#     "我 买 原油 的 时候",
#     "我 是 花 2 万美元   我 买 了 这个 原油 了",
#     "后来 还 没 等 交货   我 就 把 它 卖 了",
#     "但是 我 卖 的 时候 比 2 万 还 多",
#     "你 说 我 是不是 赚 了   对 不 对",
#     "所以 说 多方 就 赚 了",
#     "多方 一旦 要 赚 了 的话   那 你 空方 就 赔 了",
#     "为什么 呢   因为 空方 最 开始 的 时候",
#     "我 是 2 万美元 卖 了 1000 桶 原油",
#     "过 了 一段时间 没 交货   我 就 把它买 回来",
#     "但是 买回来 的 时候 价格 高",
#     "那 我 不 就 赔 了 吗   对 不 对",
#     "所以 说 空方 就败 了   所谓 败 了 就是 赔钱 了",
#     "那么 反过来说   假如 说 这个 价格下降 了",
#     "也 就是 原来 的 合约 价格 高",
#     "后来 的 合约 价格低",
#     "这个 时候 自然而然 多方 就 输 了   多方 就败 了",
#     "为什么 呢",
#     "因为 他 开始 以 比较 高 的 价格 买 了 原油",
#     "还 没 等 交割",
#     "就 把 它 以 比较 低 的 价格 卖 回去 了   对 不 对",
#     "最后 的 结果 他 就 赔钱   而 空方 就 胜 了",
#     "为什么 呢",
#     "因为 开始 的 时候   他 以 比较 高 的 价格 卖 了 原油",
#     "后来 又 以 比较 低 的 价格 买回来 了   对 不 对",
#     "所以 这个 过程 就 称之为 开仓 和平 仓",
#     "而且 这个 期货交易 和 股票交易 的 不同 在于",
#     "股票 如果 我 从 你 手里 买 股票",
#     "我要 把 钱 给 你",
#     "期货交易 不是 这样 的",
#     "咱们 立 了 约 之后 不 相互 交钱",
#     "这个 钱 只是 被 交易所 锁定",
#     "就是 保证金 交易 制度",
#     "咱们 来说 一下 保证金 交易 制度",
#     "保证金 并不一定 是 100%",
#     "不同 的 商品 这个 有 很大 的 差别",
#     "我们 举个 例子",
#     "咱们 假设 这个 WTI 原油   它 的 保证金 是 10%",
#     "那会 有 什么 特点 呢",
#     "我们 现在 有甲   这个 甲 是 一个 多方",
#     "而 乙   乙是 一个 空方   是 吧",
#     "他们 两个 人 开始 交易 原油 了",
#     "最 开始 的 时候 立约   它 的 价格 是 20000 元",
#     "20000 元 的 时候",
#     "如果 我们 按 保证金 10% 来算",
#     "那么 甲 需要 账户 里 有 多少 钱",
#     "甲 需要 账户 的 有 2000 元",
#     "如果 2000 元 没有 的话",
#     "那么 交易所 是 不会 让 你 开仓 的",
#     "同样 乙 作为 空方",
#     "它 也 要 有 2000 元 在 账户 里 待 着",
#     "这 2000 元 就 称之为 保证金",
#     "假如 是 10% 的话",
#     "结果 到 了 第二天 的 时候   这个 价格上涨 了",
#     "价格 不再 是 20000 元 了",
#     "价格 变成 了 21000 元 了",
#     "变成 了 这个 价格 了",
#     "这个 时候 我 再 问   你 说 甲会 怎么样",
#     "你 想 甲 的 意思 是 说",
#     "我们 可以 以 20000 元 的 价格",
#     "买到 1000 桶 油",
#     "但是 现在 1000 桶 油值 21000 元",
#     "所以 呢   所以 我 是不是 赚 了 1000 元 呢",
#     "赚 了 1000 元 的 时候",
#     "交易所 就 会 做 一个 变化   什么 变化",
#     "他 把 这个 账户 里 的 钱 进行 了 一下 划转",
#     "他 把 这个 乙 账户 里 的 1000 元",
#     "划到 甲 账户 里 了",
#     "甲 账户 里 就 多 了 1000 元 了",
#     "所以 甲 账户 一共 就是 3000 元",
#     "说 为什么 多 1000 元 呢",
#     "那 是因为 这个 油价 上涨 了",
#     "因为 它 上涨 了   所以 甲 的 这份 合约 就 值钱 了",
#     "所以 他 就 多 了 一些 钱",
#     "而 乙 的 账户就 被 划走 了 1000 元 了   对 吧",
#     "于是 乙 的 账户 里 只有 1000 元",
#     "这个 时候 保证金 就 不够 了   为什么 呢",
#     "因为 我们 说 保证金 假如 是 10% 的话",
#     "那么 21000 元   保证金 应该 是 2100 元",
#     "你 现在 只有 1000 元   对 吧",
#     "所以 你 少 1100 元   怎么办",
#     "这个 时候 期货 公司 就 会 跟 你 说",
#     "请 你 追加 保证金",
#     "追加 保证金   至少 追加 1100 元",
#     "如果 你 追加 了 这 1100 元 的话",
#     "那么 你 还 可以 继续 交易",
#     "如果 你 不 追加 这 1100 元 的话",
#     "那么 他 就 会 给 你 强行 平仓",
#     "好   咱们 现在 假设 乙 又 追加 了 1100 元",
#     "那 一共 账户 里 还有 2100 了",
#     "结果 到 了 第三天   这个 价格 又 变 了",
#     "这个 石油价格 变成 了 25000 元 了",
#     "那 这个 时候 甲会 怎么样",
#     "石油价格 又 上涨 了 4000 元",
#     "所以 甲 这 一份 合约 更 值钱 了",
#     "3000 加 4000",
#     "甲 账户 里 就 应该 有 7000   元",
#     "这是 交易所 划转 的",
#     "乙 呢   乙 本来 账户 里 还 剩 2100   对 吧",
#     "结果 现在 又 亏了 4000",
#     "所以 还 剩下 - 1900 元",
#     "此时 期货 公司 又 跟 你 说",
#     "你 保证金 又 不够 了   你 再 给 我 追加",
#     "这回 追加 多少",
#     "25000 元   保证金 2500",
#     "2500   你 现在 账户 是 - 1900",
#     "所以 你 得 给 我 追加 4400 元",
#     "如果 你 不 追加 4400 元 的话   会 被 强行 平仓",
#     "好 了   现在 乙说 我 没有 钱 了   所以 我 不 追加",
#     "那 如果 你 不 追加 的话   他 现在 就 进行 平仓",
#     "怎么 平仓",
#     "那 就是 甲 和 乙 之间 不是 立 了 个 约 吗",
#     "只不过 甲 立约 的 时候",
#     "乙是 按照 2 万 的 价格",
#     "2 万元 的 价格 去 卖 给 甲 原油 的",
#     "结果 现在 甲 又 把 这个 原油 卖回 给 乙 了",
#     "卖回 给 乙 的 时候 他 卖 25000",
#     "那 所以 甲 不 就 最后 赚 了 5000 元 吗",
#     "乙 最后 就 亏了 5000 元",
#     "所以 最后 甲 的 账户 里 就 会 变成 7000 元",
#     "变成 7000 元   原来 有 2000 是 你 自己 的",
#     "所以 你 就 赚 了 5000",
#     "乙 呢   乙 原来 是 有 2000",
#     "追加 了 1100   是 3100   对 吧",
#     "但是 你 还 欠 期货 公司 1900",
#     "这 1900 你 必须 得 还 上",
#     "这 就 出现 了 你 不光 本金 赔光",
#     "还 倒 欠 期货 公司 钱 的 情况",
#     "所以 期货 是 有 杠杆 的",
#     "你 可能 会 因为 一个 波动 赚 了 很多很多 的 钱",
#     "你 用 2000 元   你 赚 了 5000 元   对 不 对",
#     "但是 也 有 可能 会 亏光 本金",
#     "甚至 倒 欠 期货 公司 的 钱",
#     "所以 期货 是 一念 天堂   一 念 地狱 的",
#     "而且 期货 也 不能 长期 持有",
#     "为什么 不能 长期 持有",
#     "你 股票 可以 长期 持有",
#     "跌 了 我 不管 它   总有一天 我能 涨起来   对 不 对",
#     "期货 这么 做 是 做 不到 的",
#     "你 比如说 石油   石油价格 狂跌",
#     "我 买点 原油 我存 着",
#     "以后 石油 涨 了 我 再 卖   行不行   不行",
#     "为什么 不行",
#     "因为 它 有 一个 什么 呀",
#     "有 一个 到期日 和 交割 这么 一 说法",
#     "到期日   还有 交割",
#     "比如说 这个 WTI 原油",
#     "它 是 每 一个月 都 要 进行 交割 的",
#     "也就是说 比如说 咱们 互相 买卖 的",
#     "是 5 月份 交割 的 这个 原油",
#     "那么 到 了 这个 5 月份   到 了 这 4 月末 的 时候",
#     "它 就要 进行 交割 了",
#     "你 这个 单子 就 不能 再 交易 了",
#     "就 需要 按照 这个 字面 说 的   对 吧",
#     "到 什么 什么 地方 去 买卖 这 1000 桶 原油 了",
#     "那 如果 你 没有 这个 能力 的话",
#     "你 必须 在 到期 之前 做 这么 一个 工作",
#     "第一个 就是 平仓",
#     "什么 叫 平仓 呢",
#     "就是 如果 原来 你 卖 了 油 你 再 把它买 回来",
#     "不管 价格 是 多少",
#     "如果 你 原来 买 了 油   你 就 把 它 卖出去",
#     "也 不管 价格 是 多少",
#     "还有 一种   叫做 移仓换 月 或者 叫 展期",
#     "移仓换 月 的 意思 就是说",
#     "你 现在 咱们 买卖 的 是 5 月份 交货 的",
#     "但是 现在 马上 到期 了",
#     "所以 我 把 5 月份 交货 的 这个 期货 我 平仓",
#     "然后 我 再 去 买入 6 月份 交货 的",
#     "这样 我 就 可以 继续 买卖 了   对 吧",
#     "我 可以 继续 赚钱 了",
#     "这 就 叫 移仓换 月",
#     "那么 一般来讲   移仓换 月 都 是 发生 在",
#     "最后 交易日 之前 的 几天 的 时间",
#     "不过 这 一次 原油 宝 就 出现 了 一个 问题",
#     "它 是 正好 就 在 最后 交易日 附近 它 来 做 这个 事",
#     "结果 流动性 没有 了",
#     "就 说 你 想平   没有 人卖 给 你",
#     "所以 就 造成 了 价格 狂跌 的 这么 一个 情况",
#     "那么 如果 你 这 两件事 都 不 做",
#     "你 就 非得 等到 最后",
#     "那 就 会 出现 什么",
#     "就 会 出现 交割",
#     "交割 有 两种 方式",
#     "第一种 交割 就是 实物 交割",
#     "你 买 原油 你 就 给 原油 或者 拿 原油",
#     "第二种 是 现金 交割",
#     "那么 有 一些 是 没有 办法 实物 交割 的",
#     "比如说 咱们 炒作 的 标的 是 这个 股票指数",
#     "股票指数   股指 期货",
#     "这个 东西 你 不 可能 把 股指 卖 给 你   对 吧",
#     "最后 就是 按照 现金 进行 交割 的",
#     "那么 WTI 原油 它 就是 用 实物 交割 的",
#     "那么 具体来讲 多方 会 怎么样",
#     "假如 你 还 拿 着 多单",
#     "这多单 的 意思 是 什么",
#     "就是 我们 会以 某个 价格",
#     "以 某个 价格 去 怎么样",
#     "去 获得 1000 桶 原油",
#     "这 就是 多单 的 意思   1000 桶 油",
#     "大家 注意   你 如果 持有 多单",
#     "你 就 必须 要 做 这件 事   这 是 你 的 责任",
#     "不是 说 你 想要 就要   不 想要 我 就 给 你 不要 了",
#     "这 不行   你 必须 去 做 这件 事",
#     "以 某个 价格 去 获得 1000 桶 的 原油   是 吧",
#     "只不过 这个 价格 咱们 是 可以 商量 的",
#     "我们 举个 例子",
#     "比如说 我们 开仓 的 时候 可能 是 20 美元",
#     "我们 认为 20 美元 这个 价格 是 合理 的",
#     "你 也 认为 合理 的",
#     "结果 我 就 拿 了 一个多 单",
#     "以后 我 就 可以 以 20 美元 的 价格 获得 一桶 原油",
#     "2 万美元 的 价格 获得 1000 桶 原油 了",
#     "这个 乘 1000 我 就 不 写 了",
#     "现在 我 说 我 不 想要 原油",
#     "为什么 呢",
#     "因为 我 本身 就是 一个 炒 期货 的 投机者",
#     "我 不 想到 美国 库欣 那 去 提 原油 走",
#     "我 也 没有 那个 设备   对 不 对",
#     "好 吧   那 我 必须 要 在 到期 之前 我 把 它 平仓",
#     "好 吧   那 就 平",
#     "我 卖 20 美元 没人要",
#     "没人要 怎么办   那 我 就 卖 10 美元 吧",
#     "因为 现在 石油 消费 不行",
#     "卖 10 美元 一桶   有没有 人要",
#     "还是 没有 人要   对 吧",
#     "我 就 卖 5 美元   5 美元 还是 没有 人要",
#     "那 我 干脆 卖 0.01 美元 吧",
#     "意思 是 说 你 只要 拿 0.01 美元",
#     "你 就 可以 获得 一桶 石油",
#     "1000 桶 石油 我 只要 10 美元",
#     "这么 便宜 的 价格 还 没有 人要 吗",
#     "这个 时候 他 指望 着 谁 接单",
#     "指望 着 空方 接单",
#     "你 注意 空方 的 地位 跟 多方 是 一样 的",
#     "空方 也 必须 在 交割日 之前 把 这个 仓平 掉",
#     "否则 的话",
#     "他 就要 付出 某个 价格   提供 一些 原油 了",
#     "但 问题 是 你 不 知道 这些 空方 到底 是 干嘛 的",
#     "也许 这个 空方 背后",
#     "就是 有 大型 的 这个 石油 公司 支持 着",
#     "他们 手里 边 就是 有油",
#     "所以 空方 说 我 不怕   我 有 油",
#     "咱们 大不了 到 交割   对 不 对",
#     "交割 我 给 你 油 不 就 完 了 吗",
#     "但 问题 是",
#     "你 给 我 油   我 没有 地方 去 拉   我 没有 地方 放",
#     "现在 石油 已经 把 全世界 都 给 充满 了",
#     "美国 库欣 的 那些 油罐 都 充满 了",
#     "你 说 我 把 石油 放在 库 里边   我 不 拿走",
#     "那 不行   你 这 属于 没有 交割",
#     "这 交易所 是 要 罚 你 的 钱 的",
#     "你 说 那 我 去 找 一些 运 油车 把 它 运走",
#     "这些 运 油车 的 费用 也 可 不少   对 不 对",
#     "你 说 那 我 像 牛奶 一样   把 它 倒地 里边",
#     "那 你 可 就要 被 罚 死 了",
#     "所以 在 这种 情况 下",
#     "你 没有 能力 去 提取 这个 原油",
#     "那 你 就 必须 要 交割",
#     "人家 空方 又 不接 你 的 单   怎么办",
#     "你 只好 继续 往下压 价",
#     "于是 价格 就 变成 负 的",
#     "直到 - 37.63 美元",
#     "- 37.63 美元 什么 意思",
#     "就是 谁 接 了 我 这个 单",
#     "你 不光 可以 拿走 1000 桶 油",
#     "而且 每 一桶 油",
#     "我 还 额外 的 付给 你 37.63 美元   对 吧",
#     "我 额外 的 付给 你 37.63 美元 之后",
#     "你 可以 拿 这个 钱",
#     "去 进行 储存   运输 这个 油   对 不 对",
#     "然后 空方 说",
#     "那好 吧   我 勉为其难 接 你 这个 单子 吧",
#     "双方 就 平仓 了",
#     "其实 整个 过程 就是 这样 一个 过程",
#     "那么 当时 在 原油 宝 停止 客户 交易 的 时候",
#     "价格 大概 是 10 美元 左右",
#     "后来 在 美国 那边 的 各种 操作 下",
#     "价格 一路 狂泻 到 - 37.63 美元",
#     "不过 我 还 看到 网上 有 一个 人",
#     "这个 人亏 的 特别 惨",
#     "有 一个 个人 投资者",
#     "这个 投资者 他 怎么样 啊",
#     "他 不是 我们 原油 宝 的 用户",
#     "他 是 自己 在 网上 做 WTI 原油 的",
#     "结果 他 有 一次 发现",
#     "这个 价格 是 0.01 美元 了   对 不 对",
#     "太 便宜 了",
#     "于是 他 就 买 了 1 万美元",
#     "1 万美元   这个 单价 是 0.01 美元   是 吧",
#     "所以 大约 是 相当于 什么 呢",
#     "相当于 是 100 万桶 油",
#     "也就是说 他 付出 了 1 万美元 买 了 100 万桶 油",
#     "他心 说 那 这个 人太 划算 了",
#     "为什么 太 划算 了",
#     "因为 我 只花 了 0.01 美元 的 价格",
#     "我 就 买 到 了 一桶 油",
#     "如果 你 要是 涨价 涨到 0.02 美元",
#     "我 一卖   我 就 立刻 翻 一倍",
#     "那么 假如 涨 不 上去   也 没有 关系",
#     "我 1 万美元 拿 了 1 万桶 油",
#     "还有 比 这 更 划算 的 买卖 吗",
#     "结果 一 觉醒 来 发现   这个 价格 非但 突破 了 0",
#     "还 变成 了 - 37.63 美元 一桶",
#     "于是 你 的 账户 里 资金 变 多少 了",
#     "你 本来 是 1 万美元",
#     "现在 变成 了 - 3763 万美元",
#     "什么 意思",
#     "就是 你 不光 把 本金 亏光 了",
#     "你 还 欠 了 这个 期货 公司 3000 多万美元",
#     "所以 这个 人 就要 疯掉   是 吧",
#     "这个 原因 到底 是因为 什么",
#     "是因为 我们 对 这个 规矩 还是 没有 太 弄清楚",
#     "因为 这个 期货 它 是 美国 人 发明 的",
#     "所以 我们 中国 人要 想 跟 美国 人 玩 期货",
#     "你 首先 必须 要 非常 了解 人家 的 规矩",
#     "比如说 在 4 月 中旬 的 时候",
#     "美国 芝加哥 交易所 就 已经 说 了",
#     "原油期货 价格 可能 会跌 成负 的",
#     "那么 跌成 负 的话 会 出现 哪些 技术 问题 呀",
#     "或者 会 出现 哪些 这个 金融 的 风险",
#     "你 是不是 进行 了 充分 的 考虑",
#     "那么 如果 没有 进行 充分 的 考虑",
#     "因为 规矩 的 原因   就 很 有 可能 会 造成 亏损",
#     "所以 对于 我们 大部分 人 来讲",
#     "不 建议 大家 参与 期货市场",
#     "因为 这是 一个 非常 非常 专业 的 领域",
#     "如果 你 一点 期货 知识 都 不 懂",
#     "想 凭借 炒股票 的 那些 经验 去 炒 期货 的话",
#     "那 很 有 可能 会 赔 的 倾家荡产",
#     "大家 如果 喜欢 我 的 视频",
#     "可以 在 YouTube 账号 李永乐 老师 里 订阅 我",
#     "点击 小 铃铛 可以 第一 时间 获得 更新 信息"
#   ]
# }
# {
#   "video_id": "3TgmqH7YbcY",
#   "captions": [
#     "各位 同学 大家 好   我 是 李永乐 老师",
#     "最近 有 一个 小朋友 问 我 说",
#     "他 发现 茅台 这个 股票 的 价格 特别 贵   要 900 来 块钱",
#     "相比 来讲   招商银行 的 股票 只要 30 多 块钱",
#     "价格 差 了 将近 30 倍",
#     "他 就 问 我 茅台 的 股票 为什么 这么 贵 呢",
#     "其实 股票 的 绝对 价格 并 不 重要",
#     "我们 要 关注 的 是 股票 内在 的 价值",
#     "那么 怎么 评价 一个 股票 内在 价值 呢",
#     "今天 就 给 大家 提供 一个 很 简单 的 办法",
#     "我们 首先 来 介绍 一个 概念   名字 叫做 市净率",
#     "市净率 也 叫 PB",
#     "市净率 是 什么 意思 呢",
#     "我们 先 来 研究 一下",
#     "如果 我们 买 了 一个 公司 的 股票   我们 到底 获得 了 什么",
#     "我们 知道   一个 公司 它 是 有 资产 的",
#     "这个 资产 既 包括 有形 的 资产   比如说 厂房设备",
#     "也 包括 无形 的 资产   比如说 茅台 这个 牌子 就值 很多 钱",
#     "但是 同时 这个 公司   也 会 有 负债",
#     "我们 用 这个 公司 的 资产 再 减去 负债",
#     "就 得到 了 这个 公司 的 净资产",
#     "如果 我们 买 了 公司 的 股票",
#     "我们 就 既 承担 了 它 的 资产   也 承担 了 它 的 债务",
#     "所以 实际上 我们 所 获得 的 是 净资产",
#     "也就是说 我 买 股票 相当于 是",
#     "把 这个 公司 的 净资产 给 单独 拿 出来 了",
#     "拿 出来 了 之后 干什么 呢",
#     "我 把 它 切割成 很多 份",
#     "切割成 多少 份   是 你 公司 上市 的 时候 决定 的",
#     "这个 份数 我们 就 称之为 股本 数",
#     "很 显然 你切 的 份数 越 多   每 一份 代表 的 净资产 就 越少",
#     "其中 这 一份   我们 就 称之为 一股",
#     "这 就是 我们 买 股票 的 时候 到底 买 了 些 什么",
#     "那么   在 公司 的 资产 负债表 上",
#     "其实 它会 告诉 我们 有 多少 资产",
#     "有 多少 负债   有 多少 净资产",
#     "所以 我们 就 已 提出 这样 的 一个 算法",
#     "叫做 每股 净资产",
#     "什么 是 每股 净资产 呢",
#     "那 显而易见   每股 净资产 就是 我们 先算出 你 的 净资产",
#     "算 出 净资产 之后",
#     "我们 再 把 这个 净资产 再 除以 你 的 股本 数",
#     "这 就 得到 了 每 一股 到底 代表 了 多少 净资产",
#     "我们 来画 一个 表格   把 这个 事 研究 一下",
#     "好   这个 表格 我们 画 完 了",
#     "我们 来 对比 一下 茅台 和 招商银行",
#     "首先 我们 在 资产 负债表 上   可以 看到 它 的 净资产 总额",
#     "这个 茅台 它 的 净资产 总额 去年 1174 亿元 人民币",
#     "招商银行 是 5436 亿元 人民币",
#     "这 是 它 的 净资产",
#     "然后 我们 再说 它 的 股本",
#     "就是 你 上市 的 时候 你 发行 了 多少 股本 呢",
#     "茅台 发行 了 12.56 亿股",
#     "它 把 自己 分成 了 这么 多份",
#     "招商银行 发行 了 252.2 亿股   发行 了 这么 多份",
#     "于是 我们 用 净资产 再 除以 你 的 股本 数",
#     "就 得到 了 每股 净资产",
#     "我们 用 这 两数 一除 就行了   茅台 是 93.5 元",
#     "这 是 它 每 一股 的 股票 代表 的 背后 净资产 价格",
#     "还有 招商银行 是 21.55 元",
#     "好   这 是 它 去年 给出 的 资产 负债表",
#     "我们 得出 了 这么 一个 数据",
#     "很 显然 呢 每股 净资产 越 多   这个 股票 就 应该 越 值钱",
#     "不过 这个 股票价格 其实 是 交易 来 的",
#     "而 不是 通过 每股 净资产 算 出来 的   对 不 对",
#     "所以 我们 在 交易 的 过程 中 给 了 股票 一个 价格",
#     "于是 我们 就 会 有 第二个 概念 叫做 市值",
#     "我们 经常 听说 市值 蒸发 多少 亿   这 什么 意思",
#     "市值   就是 它 的 每股 价格",
#     "这个 每股 价格   它 是 交易 出来 的",
#     "就是 你 愿意 花 多少 钱 买   我 愿意 花 多少 钱卖",
#     "咱们 交易   撮合 的 过程 中 就 出现 了 一个 价格",
#     "然后 我用 这个 价格   再 乘以 你 的 股本 数",
#     "这样 我们 就 得到 了 市值",
#     "比如说 咱们 看 茅台",
#     "茅台 它 的 价格 现在 交易 到 900 元 一股 左右",
#     "所以 茅台 的 市值 是 多少",
#     "茅台 的 市值   我们 要用 它 的 价格 900 元 乘以 股本 数",
#     "最后 算 出来 是 1.1 万亿",
#     "也就是说 市场 所 认可 的 茅台 的 这 公司 价值 就是 这么 多",
#     "1.1 万亿",
#     "但 它 实际上 净资产 只有 1000 多亿",
#     "好   咱们 再 看 招商银行",
#     "招商银行 现在 的 股票价格 大概 是 35 元",
#     "我们 用 35 元 乘以 股本 数",
#     "得到 了 招商银行 的 市值 是 8700 亿元",
#     "这 就是 市场 给出 招商银行 这个 公司 的 价格",
#     "但 实际上 它 净资产 只有 5000 多亿",
#     "好   我们 第二个 概念 市值 也 得 出来 了",
#     "那么 下面 我们 说 下 一个 概念 叫 市净率 了",
#     "我们 会 发现 这个 公司 的 净资产 一般来讲 是 小于 市值 的",
#     "就是 市场 对 你 的 估值   其实 比 你 的 实际 资产 要 多",
#     "那么 二者 的 比例 是 多少 呢",
#     "我们 可以 用 市值 再 去除 以 你 的 净资产",
#     "同时 我们 知道 市值 是 每股 价格 乘以 股本 数",
#     "净资产 是 每股 净资产 乘以 股本 数",
#     "所以 他俩 一除 也 等于 什么",
#     "也 等于 每股 的 价格 再 除以 每股 的 净资产",
#     "也就是说 我们 用 市场 给出 的 价格",
#     "再 除以 会计 给出 的 价格",
#     "这个 东西 我们 就 称之为 市净率 PB",
#     "市净率 越高 就 说明 市场 对 你 越 认可",
#     "因为 你 的 股价 相比 于 你 的 资产 来讲 高 了",
#     "市净率 越低   就 说明 你 股票 越 低估",
#     "我 买入 可能 我会 赚 的 比较 多   对 吧",
#     "好   我们 来看 一下 茅台 和 招商银行 的 市净率 是 多少",
#     "我们 用 它 的 价格 900 元 再 除以 每股 净资产 93.5 元",
#     "这么 一 算   茅台 的 市净率 是 9.6",
#     "也就是说   这个 市场 对于 茅台 的 估计 超过 了 它 净资产 9 倍   对 吧",
#     "咱们 再 看 招商银行",
#     "我们 用 价格 35 元 除以 每股 净资产 21.55",
#     "得到 的 是 1.6",
#     "也就是说   市场 认为 招商银行 的 价值",
#     "是 它 实际 会计 资产 的 1.6 倍",
#     "这是 市净率 的 一个 概念",
#     "那么 我们 在 选股 的 时候",
#     "如果 我们 选 市净率 低 的   可能 相对 来讲 是 比较 安全 的",
#     "但是 市净率 并 不能 代表 公司 的 全部 价值",
#     "因为 公司 是 要 创造 利润 的   你 光是 资产 多 没有 用",
#     "你 资产 多   最后 一点 价值 不 创造   对 吧",
#     "最后 我 只能 破产 清算   这个 没什么 用",
#     "我们 要 看 的 是 这 公司 有 多少 利润",
#     "所以 人们 又 发明 了 第二个 指标 叫 市盈率",
#     "市盈率 我们 管它 叫 PE",
#     "什么 叫 市盈率 呢",
#     "这个 股票 可以 创造 价值   创造 利润",
#     "每股 的 利润 有 多少 呢",
#     "显而易见   每股 的 利润 应该 等于 你 这个 公司 的 净利润",
#     "所谓 净利润 就是 你 刨除 了 员工 成本",
#     "刨除 的 税费 之类 的   剩下 这个 钱 叫 净利润",
#     "净利润 你 是 可以 分配 的",
#     "当然 你 也 可以 不 分配",
#     "我们 用 净利润 再 除以 一个 股本 数",
#     "就 得到 了 每 一股 能够 创造 的 利润",
#     "我们 来 分析 一下 这 两只 股票",
#     "净利润 是 多少",
#     "根据 他们 的 财报 在 2018 年 的 时候",
#     "茅台 的 净利润 是 352 亿元 人民币",
#     "然后 我们 把 这个 数 除以 股本 数 就 得到 了 每股 净利润",
#     "每股 净利润   那 是 多少 呢   352 亿再 除以 一个 12.56 亿",
#     "最后 算 出来 每股 净利润 是 28 元",
#     "这 就是 每股 茅台 可以 创造 的 价值",
#     "咱们 再 看 招商银行",
#     "它 去年 的 时候 净利润 是 806 亿元",
#     "然后 我们 把 它 再 除以 股本 数   除 完 了 之后 大概 是 3.13 元",
#     "会 差一点 不是 很 严格 相等   因为 有 一些 会计 处理 的 问题",
#     "好   这 就是 两个 股票 可以 创造 的 价值",
#     "下面 我们 再 来看 什么 是 市盈率",
#     "你 现在 每 一股 都 有 利润 了   我们 要 想 算 你 的 市盈率",
#     "我们 可以 这么 算",
#     "市盈率 它 等于 你 的 股票价格   或者 叫 每股 的 价格",
#     "再 去除 以 你 的 每股 利润   这个 就 叫 市盈率",
#     "它 是 在 分析 的 时候 最 有效 的 一个 指标",
#     "这个 每股 价格 除以 每股 利润   这 就 叫 市盈率",
#     "我们 来看 一下 这 两只 股票   市盈率 是 多少",
#     "茅台 这支 股票 它 的 价格 是 900 元",
#     "它 每 一股 每年 可以 创造 比如 28 块钱 的 利润",
#     "所以 我们 把 这 两个 数 相除 就 得到 了 市盈率",
#     "市盈率 大概 是 32",
#     "就 用 这个 数 除以 这个 数 就行了   32",
#     "32 是 什么 意思",
#     "就是 你 花 900 块钱 买 了 一股",
#     "它 每股 每 一年 只能 创造 28 块钱 的 利润",
#     "所以 你 要 想 把 自己 全部 的 投资 拿 回来",
#     "你 需要 多少 年   理论 上 讲 需要 32 年",
#     "那 也就是说   假如 茅台 的 盈利 性能 每 一年 都 是 一样 的",
#     "过 了 30 多年 之后 你 这个 钱 就 挣 回来 了",
#     "当然   挣 回来 不 一定 分给 你",
#     "除非 分红 才能 分给 你   否则 不能 分给 你",
#     "只是 用于 公司 的 扩大",
#     "咱们 再 看 招商银行   招商银行 它 的 价格 是 35 元",
#     "它 的 每股 净利润 是 3.13 块",
#     "我们 用 这 两数 一除 就 得到 它 的 市盈率   大概 是 11 倍",
#     "也就是说   招商银行 如果 你 投资 花 35 块钱 买 了 一股",
#     "理论 上 讲 11 年 这 公司 创造 价值 就 可以 赢回 你 这个 股票 了",
#     "那 我们 来看 一看   我们 从 刚才 讨论 的 两个 指标",
#     "一个 叫 市净率   一个 叫 市盈率",
#     "市净率 是 看 这个 股票 的 价格 超过 它 净资产 多少倍",
#     "这样一来 看 茅台 9 倍 多   招商银行 1.6 倍",
#     "所以 茅台 比 招商银行 贵   贵 多少   大概 贵 6 倍",
#     "茅台 贵 一些   贵 了 6 倍",
#     "我们 再 看 市盈率   茅台 需要 30 多年 才能 把 这个 钱 赚 回来",
#     "而 招商银行 需要 11 年",
#     "所以 茅台 还是 贵   但是 这回 贵 的 就 没 那么 厉害 了",
#     "它 不是 贵 6 倍   而是 贵 大概 3 倍",
#     "说明 它 的 盈利 性能 可能 会 比较 好 一些   对 不 对",
#     "但是 贵 3 倍 也 是 差 不少   其实 我们 还有 一个 指标",
#     "什么 指标 呢",
#     "市盈率 这个 东西 它 没有 考虑 到 公司 的 成长性",
#     "就 这个 公司 茅台 今年 赚 了 28 元 每股",
#     "明年 它 可能 会 翻 1 倍",
#     "明年 如果 翻 1 倍   那 市盈率 一下子 变成 16 倍 了",
#     "如果 后 年 再 翻 1 倍   它 市盈率 就 变 8 倍 了",
#     "所以 市盈率 变化 是 非常 快 的",
#     "那 我们 能 不能 把 它 的 增长 也 考虑 进去 呢",
#     "人们 又 发明 了 一个 参数   名字 叫 市盈 增长 比",
#     "这个 参数 叫 PEG",
#     "它 就是 把 公司 的 成长性 也 考虑 进去 了",
#     "市盈 增长 比 等于 什么 呢",
#     "它 等于 这个 公司 的 市盈率   也 就是 PE",
#     "再 去除 以 它 的 平均 年增长率",
#     "然后 再 乘以 一个 100   等于 这么 一个 数",
#     "比如说 我们 来看 茅台",
#     "茅台 在 最近 五年 我 统计 了 一下",
#     "它 增长率 的 平均值 大概 是 20%",
#     "就是 它 每 一年 的 利润 都 比前 一年 多 20%   平均 来讲",
#     "而 招商银行 每 一年 的 利润 大概 比前 一年 多 了 9.3%",
#     "多 了 这么 多",
#     "好   我们 现在 用 市盈率 再 除以 增长率 乘 100",
#     "除 完 了 之后 我们 就 会 得到 市盈 增长 比   叫 PEG",
#     "32 / 20 得 几   得 1.6",
#     "同样 招商银行   我们 用 11 / 9.3 得 几   得 1.2",
#     "我们 比较 一下   从 这 一 角度 来看 这个 PEG 参数 还是 茅台 贵",
#     "招商银行 便宜   但是 贵 的 就 没有 那么 多 了",
#     "这回 茅台 价格 只是 招商银行 的 4 / 3 倍",
#     "所以 你 从 这 几个 参数 看   市净率 茅台 贵 了 6 倍",
#     "市盈率 茅台 贵 3 倍",
#     "但是 市盈 增长 比 茅台 只 比 招商银行 贵 了 4 / 3",
#     "也 就是 贵 了 30% 多   对 不 对",
#     "所以 茅台 的 价格 其实 并 没有 那么 贵",
#     "它 主要 是因为 它 每股 的 资产   每股 的 盈利",
#     "以及 它 的 增长 性 都 非常 好",
#     "相比 于 很多 题材股   茅台 其实 并 不贵",
#     "当然 招商银行 就 更 便宜 了",
#     "所以 我们 在 选 股票 的 时候 有 什么 方法 可以 避免 踩 雷 呢",
#     "其实 有 一个 很 简单 的 办法   就 看 这 三个 参数",
#     "第一个 参数 叫 市净率",
#     "市净率 越低   那么 这个 股票 资产 就 越 值钱",
#     "还有 一个 叫 市盈率   市盈率 越低 说明 它 盈利 性能 越 好",
#     "还有 一个 是 市盈 增长 比   如果 市盈 增长 比率 越低",
#     "就 说明 它 的 成长性 和 价格 都 比较 合适",
#     "这 三个 参数 如果 都 比较 低 了",
#     "那 这个 股票 可能 就是 一个 比较 优质 的 股票",
#     "长期投资 的 情况 下 它 有 可能 使 你 赚钱",
#     "那 如果 这 三个 数都 非常 非常 高",
#     "都 成百上千   这 就 说明 什么   说明 这个 股票 是 一个 题材股",
#     "它 有 很大 的 风险",
#     "当然 了   股票 这个 东西 其实 风险 一直 都 很大   是 说 不准 的",
#     "就 像是 牛顿 这样 伟大 的 科学家 炒股 的 时候",
#     "也 赔掉 了 自己 十年 的 工资",
#     "那 牛顿 为什么 赔掉 自己 十年 的 工资 呢",
#     "咱们 下 一回 再 给 大家 讲 一 讲 历史 上 著名 的 股灾",
#     "大家 如果 喜欢 我 的 视频",
#     "可以 在 YouTube 帐号 李永乐 老师 里 订阅 我",
#     "点击 那个 小 铃铛 可以 第一 时间 得到 更新 提示"
#   ]
# }
# {
#   "video_id": "3hIqEis4d9I",
#   "captions": [
#     "各位 同学 大家 好   我 是 李永乐 老师",
#     "这个 \" 五一 \" 你 出门 旅游 了 吗",
#     "到处 都 是 人山人海",
#     "许多 小朋友 给我发 来 私信 问",
#     "既然 明明 知道 \" 五一 \" 出游 会人 多",
#     "大家 为什么 还要 拼命 地 出去 旅游 呢",
#     "这个 问题",
#     "我 想 用 马斯洛 的 《 需求 层次 理论 》",
#     "和 大家 一起 分析 一下",
#     "如果 你 听懂 了 这个 理论",
#     "那么 你 会 发现 无论是 在 工作 当中",
#     "还是 在 子女教育 当中",
#     "这个 理论 都 是 很 有用 的",
#     "我们 来讲 一讲 马斯洛 的 需求 层次 理论",
#     "马斯洛   美国 心理学家",
#     "当 过 美国 心理学 会 的 会长",
#     "他 是 人本主义 的 代表 人物",
#     "他 在 1943 年 的 时候",
#     "提出 了 需求 层次 的 理论",
#     "这个 理论 有 三个 基本 的 观点",
#     "第一个 观点   人会 有 不同 的 行为",
#     "行为 是 怎么 产生 的 呢",
#     "是因为 人有 动机   所以 才 产生 了 行为",
#     "那么 人 为什么 会 有 这样 的 动机 呢",
#     "这 是因为 人有 需求",
#     "不同 的 需求 就 会 产生 不同 的 动机",
#     "而 不同 的 动机 又 会 产生 不同 的 行为",
#     "人 的 需求 是 分 层次 的   从 低 到 高",
#     "最初 他 提出 了 五个 需求 的 层次",
#     "我们 来说 一下 人 的 需求 层次",
#     "需求 层次",
#     "哪 五个 需求 层次 呢",
#     "最低 的 需求 层次 是 生理 的 需求",
#     "生理 的 需求",
#     "比如说 人 需要 食物   对 吧",
#     "人 需要 水   人 需要 空气",
#     "人 需要 睡眠   人 还 需要 性 等等 吧",
#     "这些 都 是 最起码 的 生理需求",
#     "如果 缺乏 了 这些 生理 的 需求",
#     "那么 人 就 会 生病",
#     "所以 为了 满足 这些 生理需求",
#     "人 就 会 产生 一些 行为",
#     "举个 例子 来讲   我们 要 工作",
#     "这样 我们 就 可以 获得 工资",
#     "我们 就 可以 满足 我们 的 生理需求 了",
#     "但是 假如 我们 没有 办法 通过 工作",
#     "来 满足 生理需求 的话",
#     "那么 我们 的 道德感 就会 变低",
#     "我们 就 会 抢劫   对 吧",
#     "比如 在 动荡 的 地区",
#     "就 有 可能 会 出现 大规模 的 抢劫 的 行为",
#     "那么 比 生理需求 高一 层次 的 是 安全 的 需求",
#     "人有 安全 的 需求",
#     "这个 安全 需求 包括 身体 的 安全",
#     "包括 财产 的 安全   包括 事业 的 安全 等等",
#     "就 比如说 我们 为什么 要 体检 呢",
#     "因为 我们 害怕 身体 出毛病",
#     "这是 对于 身体 安全 的 需求",
#     "我们 需要 买 养老保险   买 汽车保险",
#     "这是 对于 我们 的 事业",
#     "对于 我们 的 财产 的 安全 的 需求",
#     "如果 安全 的 需求 出现 匮乏",
#     "那么 人 就 会 变得 恐惧 和 焦虑",
#     "恐惧 源于 未知",
#     "比如 一个 孩子",
#     "他 处于 一个 不可 预测 的 环境 之中",
#     "每天 回到 家 都 不 知道 他 爸爸 会 不会 揍 他",
#     "那 这个 孩子",
#     "往往 就 会 处于 一种 恐惧 和 焦虑 之中",
#     "第三个 层次 的 需求 叫 爱 和 归属",
#     "爱 与 归属",
#     "比如说 爱",
#     "人 需要 很 多种 情感",
#     "比如说 像 亲情   爱情   还有 友情   对 吧",
#     "人 还 需要 进行 社交",
#     "人 是 一种 社会 动物",
#     "他 需要 把 自己 归 到 一个 集体 当中 去",
#     "人 一旦 缺乏 了 爱 与 归属 的 需求",
#     "就 会 主动 去 寻找 它",
#     "比如 有些 少年",
#     "他 为什么 主动 加入 一些 不良少年 的 群体",
#     "甚至于 不惜 主动 地 吸烟   酗酒   打架斗殴",
#     "这 是因为 他 缺少 了 爱 和 归属感",
#     "他 觉得 如果 我 吸烟   酗酒   打架斗殴 的话",
#     "我 就 可以 加入 一个 小 群体 了",
#     "这样 我 就 有 了 归属感   有 了 集体 了",
#     "像 宗教 起到 的 作用 也 是 给 人 一种 归属感",
#     "第四个 层次 叫 尊重 的 需求",
#     "尊重   尊重 又 分为 两个 方面",
#     "一个 是 自我 尊重   也 就是 自信",
#     "另外 一个 是 其他人 的 尊重",
#     "收获 其他人 的 尊重",
#     "这 也 是 我们 的 一个 需求",
#     "那么 人 如果 缺乏 了 这种 需求",
#     "他 往往 表现 就是 自卑",
#     "自卑 的 行为 有 很 多种",
#     "比如说 爱慕 虚荣   是 吧",
#     "明明 没有 钱   就 很 自卑",
#     "他 非要 买 一个 LV 的 包   爱马仕 的 包   对 吧",
#     "以 显示 自己 好像 生活 很 富足   是 吧",
#     "再 比如说 明明 他 学习成绩 不是 很 好",
#     "但是 每到 老师 提问 的 时候",
#     "他 一定 要 抢 着 回答",
#     "让 别人 感觉 好像 自己 是 很会 的",
#     "这种 自我表现 的 行为",
#     "往往 是因为 缺乏自信",
#     "渴望 通过 这种 方式 来 收获 其他人 的 尊重",
#     "更 高层次 的 需求 叫做 自我实现",
#     "当 我们 之前 的 需求 都 满足 的 差不多 了",
#     "那么 人 就 有 一种 自我实现 的 需求 了",
#     "自我实现 的 需求",
#     "就是 要 实现 个人 的 理想 与 抱负",
#     "个人 的 理想 与 抱负",
#     "是 一种 高级 的 需求   最高 层次 的 需求",
#     "人 如果 缺乏 了 自我实现 的 需求",
#     "就 会 感觉 到 空虚",
#     "有 一些 大 老板 他前 四个 需求 都 达到 了",
#     "非常 有钱   受到 人 的 尊敬",
#     "结果 抑郁 了",
#     "为什么 呢",
#     "因为 他 没有 达到 自我实现",
#     "那 后来 他 找到 了 一种 自我实现 的 方法",
#     "那 抑郁 不 就 好 了",
#     "好   那么 最 开始",
#     "马斯洛 就 认为 人 的 需求 就是 有 这么 五种",
#     "那 后来 又 添加 了 两个 层次 的 需求",
#     "就是 在 第四 级 和 第五 级 之间",
#     "它 添加 了 两个",
#     "一个 需求 叫做 求知 的 需求",
#     "求知 的 需求",
#     "就是 如果 我们 达到 了 前 四个 需求 了",
#     "我们 就 开始 有 一个 求知欲 了   是 吧",
#     "有 这个 好奇心",
#     "还有 一个 就是 审美 的 需求",
#     "比如说 我们 要 去 画展   我们 要 去 音乐会",
#     "这些 都 是 审美 的 需求",
#     "这个 就 变成 了 七个 层次",
#     "而且 这些 个 层次 是 逐级 递进 的",
#     "我们 可以 把 它 画成 一个 金字塔",
#     "画成 一个 金字塔 的 形状",
#     "比如 我 就 以 五个 层次 为例",
#     "最低 层次 的 生理需求",
#     "第二 层次 的 安全 需求",
#     "第三 层次 爱 与 归属",
#     "第四 层次 的 尊重 和 第五 层次 的 自我实现",
#     "我们 不妨 打个比方",
#     "我们 就 以 《 西游记 》 为例",
#     "《 西游记 》",
#     "唐僧 师徒 其实 一共 是 五个 人   对 吧",
#     "四个 人 再加 一个 白龙马   一共 是 五个 人",
#     "这 五个 人 他们 的 需求 其实 就是 不 一样 的",
#     "比如说 猪八戒 他 是 什么 需求",
#     "猪八戒 的 需求   那 很 显然 它 就是 生理需求",
#     "每天 就 只 想 吃 馒头",
#     "还有 一个 就是 想着 高老庄 的 高 小姐",
#     "所以 他 的 基本 需求 就是 生理需求",
#     "那 白龙马 呢",
#     "白龙马 的 需求 就 不再 是 生理需求 了",
#     "白龙马 的 需求 主要 是 安全 的 需求   是 吧",
#     "白龙马 因为 受罚",
#     "每 过 七天 就 会 有 天剑来 穿 他 的 胸膛",
#     "非常 痛苦   是 吧",
#     "那 如果 加入 了 这个 团队 之后",
#     "他 就 可以 不受 天剑 的 这种 惩罚 了",
#     "他 感觉 到 非常 安全",
#     "所以 他 任劳任怨 地 驮 着 唐僧   对 不 对",
#     "而 这个 沙和尚",
#     "他 的 需求 实际上 是 团队 的 需求",
#     "是 归属感 的 需求",
#     "你 看   每当 要分 行李 的 时候",
#     "沙和尚 就 去 找 大 师兄   找 二 师兄",
#     "因为 什么 呢",
#     "因为 沙和尚 也 是 受罚 的",
#     "他 长相 非常 丑陋   没有 人理 他   对 吧",
#     "所以 他 只有 在 这个 团队 里 才能 找到 自我",
#     "才能 找到 归属感   找到 爱",
#     "所以 他 特别 害怕 散伙",
#     "那 孙悟空 呢",
#     "孙悟空 特点 是 他 没有 生理 什么 需求",
#     "他 不 讲究 吃   不 讲究 喝",
#     "他 没什么 安全 需求   他 最 厉害   是不是",
#     "他 也 没有 什么 爱 与 归属感 的 要求",
#     "他 无所谓   散伙 不 散伙 也 没有 关系",
#     "但 他 最 看重 的 是 什么",
#     "是 自己 的 名声",
#     "别人 一说 他 是 齐天大圣",
#     "他 就 高兴   洋洋自得",
#     "说 五百年 前 大闹天宫 的 孙悟空",
#     "他 就 洋洋自得",
#     "一说 你 是 个弼 马温   他 就 特别 生气",
#     "这 说明 什么",
#     "这 说明 孙悟空 他 需要 的 是 尊重 的 需求",
#     "他 需要 尊重 的 需求",
#     "他 是 第四 层次 的",
#     "那么 唐僧 呢",
#     "唐僧 前 几个 需求 他 都 不 需要",
#     "他 不 讲究 吃   不 讲究 穿",
#     "而且 还是 御弟   是不是",
#     "女儿国 国王 还 想 跟 他 结婚",
#     "所以 他 什么 都 不 需要",
#     "他 唯一 想要 的 一件 事儿",
#     "就是 取回 真经",
#     "所以 他 的 需求   主要 的 需求 是 自我实现",
#     "唐僧 是 自我实现 的 需求",
#     "所以 你 会 发现 一部 《 西游记 》",
#     "它 其实 讲 的 故事 和 马斯洛 的 需求 层次 理论",
#     "是 非常 非常 接近 的",
#     "那么 马斯洛 的 第三个 观点 是 什么 呢",
#     "他 说   当 这个 低层次 的 需求",
#     "低层次 的 需求 得到 了 相对 满足 的 时候",
#     "不 可能 绝对 满足",
#     "但是 当 低层次 需求 得到 相对 满足 的 时候",
#     "这个 高层次 的 需求",
#     "高层次 的 需求 就 会 成为 动机 的 主因",
#     "就是 动机 它 是 有 很多 需求 共同 造成 的",
#     "但 具体 哪个 需求 的 作用",
#     "最 明显   最 直接   最 重要 呢",
#     "那 你 就 得 看 哪个 需求 已经 得到 满足 了",
#     "前面 的 需求 得到 满足 了",
#     "那 就是 后 一个 需求 成为 主因 了   是 吧",
#     "我们 可以 画 一个 图像",
#     "横坐标 是 心理 的 发展",
#     "横坐标 是 心理 的 发展",
#     "纵坐标 是 它 所 产生 的 动机 的 强度",
#     "那 生理 的 需求 是 这个 样子 的",
#     "生理 的 需求 随着 这个 心理 的 发展",
#     "就 逐渐 地 降低 了",
#     "那 最 开始 的 时候",
#     "生理需求 是 最 强烈 的   对 吧",
#     "然后 发展 到 一定 程度",
#     "第二 层次 的 需求 就 成为 动机 的 主因 了",
#     "就是 安全 的 需求",
#     "再 发展 到 一定 程度",
#     "第三 层次 的 又 成为 主因 了",
#     "再 发展 到 一定 程度",
#     "第四 层次 的 又 成为 主因 了   是 吧",
#     "再 发展 到 一定 程度",
#     "第五 层次 的   也 就是 自我实现 成为 主因 了",
#     "自我实现 是 最高 层次",
#     "如果 一个 人 发展 程度 比较 低",
#     "那 生理需求 就 成为 最 主要 的",
#     "比如 战乱 地区 或者 出现 了 大 的 疾病   是 吧",
#     "最起码 得 活着",
#     "如果 生理需求 得到 满足 了",
#     "那么 它 的 安全 需求",
#     "就 成为 动机 的 主要 原因 了   是 吧",
#     "他 得 保证 自己 的 安全",
#     "如果 这 两个 都 满足 了",
#     "那么 爱 和 归属 就 成为 主要 原因 了",
#     "比如说 一个 小孩 他 早恋   是 吧",
#     "那 早恋 就 说 这 是 好事   为什么 呢",
#     "这 早恋",
#     "就 说明 他 已经 追求 第三 层次 的 需求 了",
#     "说明 他前 两个 层次 都 已经 得到 满足 了",
#     "那 如果 你 每天晚上 回家 揍 他 一顿",
#     "他 肯定 不会 早恋 的",
#     "他 一定 会 自卑   是 吧",
#     "一定 会 害怕 跟 别人 接触",
#     "所以 早恋 未尝 也 不是 一件 好事   是 吧",
#     "那么 如果 这些 都 得到 满足 了",
#     "他 就 会 去 寻求 尊重",
#     "让 很多 小孩 学习   他 学习 的 时候",
#     "他 就是 想 显摆 一下 自己 比 别人 厉害   是 吧",
#     "这 就是 因为 他 已经 在 追求 第四个 层次",
#     "希望 获得 尊重   是 吧",
#     "如果 这些 都 得到 满足 了",
#     "那 就 一个 人 什么 都 满足 了",
#     "他会 怎么样",
#     "他会 追求 自我实现   是 吧",
#     "带领 人类 走向 未来",
#     "寻求 新 的 科学 发现   对 吧",
#     "一个 登山者",
#     "就是 要 征服 世界 上 所有 的 高山",
#     "这个 就 都 属于 第五 层次 自我实现 的 需求",
#     "而且 马斯洛 还 说",
#     "当 一个 人",
#     "在 追求 自我实现 这个 需求 的 过程 中",
#     "会 有 一种 叫做 高峰 体验   叫做 高峰 体验",
#     "什么 叫 高峰 体验 呢",
#     "他 说   这 就是 一种 极致 的   忘我 的 快乐",
#     "比如说 一个 艺术家",
#     "创作 出 一个 特别 美的 曲子",
#     "在 创作 过程 中",
#     "他 感觉 到 时间 都 不 流逝 了   是 吧",
#     "这个 就是 一种 高峰 的 体验",
#     "说 有 一个 科学家",
#     "他 在 攻克 一个 科学 难关 的 过程 中",
#     "可以 几天几夜 不 睡觉   为什么 呢",
#     "因为 他 进入 了 一种 高峰 的 体验",
#     "这种 高峰 的 体验",
#     "其实 我们 每 一个 人 都 可能 经历 过   是 吧",
#     "你 可以 想象 一下",
#     "你 是否 在 某 一次 自我实现 的 过程 之中",
#     "有过 这样 的 一种 体验   是 吧",
#     "这是 最高 层次 的 时候",
#     "人会 遇到 的 高峰 体验",
#     "我们 利用 马斯洛 的 《 需求 层次 理论 》",
#     "其实 可以 指导 我们 的 一些 行为",
#     "比如 我们 想 管理 好 一个 公司 该 怎么办 呢",
#     "首先 我们 应该 给 员工 提供 足够 的 工资",
#     "用来 满足 他们 的 生理需求   是 吧",
#     "你 要是 不 满足 他 生理需求 的话",
#     "他 可能 会 去 找 兼职 来 做   对 吧",
#     "然后 第二   你 得 给 他 提供 足够 的 安全",
#     "不能 没有 五险 一金   不能 动不动 就 失业",
#     "否则 他 也 没有 办法 安心 做 的 工作",
#     "同时 应该 给 他 提供 足够 的 归属感",
#     "所以 为什么 公司 搞 团建 呢",
#     "就让 大家 觉得",
# ...
#     "那么 低速 的 时候",
#     "燃油 发动机 没有 办法 获得 高 的 效率",
#     "就 用 电动机 来 驱动",
#     "那么 高速 的 时候   需要 获得 比较 大 的 功率",
#     "或者 在 加速 超车 的 时候",
#     "需要 获得 瞬时 的 高 扭矩",
#     "就 用 燃油 发动机",
#     "这样 就 能 发挥 二者 的 优势",
#     "这 就是 混动 汽车",
#     "混动 汽车 既有 烧油 的 内燃机",
#     "又 有 用电 的 电动机",
#     "一般来讲",
#     "混动 车间 具有 燃油 车 和 电动车 的 优点",
#     "燃油 车 功率 大 没有 里程 焦虑",
#     "而 电动车 驾驶 体验 好   加速 快   更加 节能",
#     "但是 两台 发动机",
#     "具体 怎么 驱动 同一 台 汽车 的 前进",
#     "又 有 很多 的 技术 路线 选择",
#     "大家 在 上 中学 的 时候   学过 电路",
#     "你 还 记得 灯泡 之间 的 串联 并联 和 混联 吗",
#     "混合 动力 汽车 的 动力系统 也 可以 分为 这三类",
#     "串联 模式 的 增 程式 混 动车",
#     "就是 燃油 发动机 驱动 发电机",
#     "然后 发电机   再 去 带动 电动机",
#     "电动机 用来 驱动 汽车 前进",
#     "汽车 电池 起到 了 调节 电能 的 作用",
#     "汽车 低速 行驶 的 时候",
#     "发电机 发出 的 电多",
#     "而 电动机 需要 的 电少",
#     "发电机 就 把 一部分 电能 储存 在 电池 里",
#     "汽车 猛 加速 的 时候   发动机 发 的 电少",
#     "而 电动机 需要 的 电多",
#     "电池 就 会 向 电动机 提供 额外 的 电能",
#     "也许 有人 觉得 奇怪",
#     "明明 可以 直接 用 燃油 发动机 来 驱动 汽车",
#     "干嘛 非要 在 发电机 电动机 这里 折腾 一圈",
#     "这 不是 白白浪费 了 能量 吗",
#     "其实 通过 这么 一 折腾 能够 保证",
#     "无论是 低速 行驶 还是 临时 停车",
#     "发动机 一直 都 处于 高效率 的 扭矩 和 转速 下",
#     "所以   就 能够 提高 燃油 的 利用率",
#     "增 程式 汽车 的 典型 代表 是 理想 ONE",
#     "第二种   是 并联 模式 的 混动 汽车",
#     "燃油 发动机 和 电动机 地位 相同",
#     "动力 都 可以 输出 给 汽车",
#     "除了 燃油 经济性",
#     "这种 方式 可以 带来 比较 大 的 汽车 功率",
#     "假如 燃油 发动机 的 功率 是 100 千瓦",
#     "而 电动机 的 功率 是 80 千瓦",
#     "那么 整个 汽车",
#     "能够 达到 的 最大 输出功率",
#     "就是 180 千瓦 了",
#     "起步 的 加速 性能 会 比较 好",
#     "那么 这种 方式 的 主要 麻烦 在于 技术 比较复杂",
#     "需要 通过 一套 比较复杂 的 离合器 和 变速器 系统",
#     "将 两个 动力 混合 起来",
#     "比较 典型 的 代表 是",
#     "长安汽车 的 蓝鲸 iDD 混 动系统",
#     "串联 更 省油",
#     "并联 功率 大",
#     "那 要是 把 它们 结合 起来",
#     "这 就是 串并联 结合 的 混动 汽车",
#     "这种 车",
#     "至少 需要 一台 燃油 发动机 和 两台 电动机",
#     "你 可以 理解 成 一台 增 程式 系统",
#     "又 并联 了 一台 电动机",
#     "汽油 发动机 和 两台 电动机 的 动力",
#     "可以 随意 的 混合",
#     "比如 汽车 刚 起步 的 时候",
#     "可以 利用 并联 的 电动机 来 驱动 汽车",
#     "低速 的 时候   电动机 扭矩 大   噪音 小",
#     "这 就是 纯电 模式",
#     "当 汽车 超车 的 时候",
#     "司机 深 踩油门 踏板",
#     "燃油 发动机 和 并联 电动机",
#     "一起 输出 动力 驱动 汽车",
#     "这 就是 并联 模式",
#     "如果 要 爬坡 超车",
#     "那 就 需要 更大 的 功率",
#     "这个 时候 两台 电动机 和 内燃机 火力 全开",
#     "这 就是 全 功率 模式",
#     "如果 汽车 平稳 的 在 高速 上 行驶",
#     "就 可以 只用 内燃机 来 带动 汽车 了",
#     "这 就是 直驱 模式   等等",
#     "这种 模式 的 混 动系统",
#     "代表 车型 是 吉利 的 星越 L 雷神 汽车",
#     "由于 电动机 效率 远高于 燃油 发动机",
#     "那么 许多 车   还有 动能 回收 系统",
#     "可以 把 刹车 的 一部分 能量 回收 起来",
#     "所以 当年 丰田 普瑞斯 出现 的 时候",
#     "不 充电 只 加油",
#     "而 油耗 却 可以 低到 每 100 千米 3.2 升",
#     "许多 人 都 惊呆 了",
#     "我 身边 有 一个 物理 老师 连呼 不 可能",
#     "说 这样 是 违反 能量 守恒定律 的",
#     "看起来 那个 时候",
#     "大众 对于 混合 动力 汽车 还是 有 一些 误解 的",
#     "由于 节能 环保 的 原因",
#     "电动车 一定 是 未来 汽车 的 发展 方向",
#     "但是 在 电池 技术 还有 待 提高",
#     "充电 桩 并 没有 那么 普及 的 现在",
#     "混合 动力 汽车 是 很 好 的 过渡 车型",
#     "现在 的 电动车 市场 群雄 并 起",
#     "各家 都 有 各家 的 独门 绝技",
#     "不 知道 20 年 之后 回头 再 看",
#     "到底 谁 才能 问鼎 华山 之巅 呢",
#     "汽车 的 故事 我们 就 讲 到 这里 了",
#     "欢迎 大家 继续 关注 我 的 频道",
#     "李永乐 老师",
#     "我会 给 大家 带来 更 多 有趣 的 知识"
#   ]
# }
# {
#   "video_id": "OpQo58RuByI",
#   "captions": [
#     "各位 同学   大家 好   我 是 李永乐",
#     "清华大学 2009 届 的 毕业生",
#     "我 毕业 于 清华大学电子工程系",
#     "是 罗毅 老师 实验室 的 学生",
#     "我 的 导师 叫 郝智彪",
#     "今天 我 非常 非常 荣幸 能够 再次 来到 母校",
#     "来到 我 曾经 工作 和 学习 过 的 地方",
#     "然后 我来 给 大家 讲 一 讲 我 的 经历",
#     "我 希望 我 的 经历 能够 给 大家 一点 启示",
#     "我 也 非常 非常 的 希望 能够 和 在座 的 各位 成为 同事",
#     "在 十年 以前 我 即将 从 清华大学 毕业 的 时候",
#     "我 去过 很多 公司 面试",
#     "比如说 我 去过 索尼 北京 总部",
#     "当 我 来到 索尼 的 北京 总部 的 时候",
#     "我 看到 富丽堂皇 的 建筑   瞠目结舌",
#     "因为 我 到 北京 这么 多年 一直 在 中关村 附近 活动",
#     "我 从来 没有 见过 那么 辉煌 的 建筑",
#     "面试 到 最后 的 时候 面试官 问 了 我 一个 问题",
#     "他 说   你 对 工作 有 什么 要求",
#     "然后 我 说 了 三个 字   不 加班",
#     "然后 就 没有 然后 了",
#     "后来 我 又 去 了 莱曼 兄弟 面试",
#     "在 莱曼 兄弟 面试 的 时候",
#     "面试官 问 我 一个 问题",
#     "你 怎么 处理 你 自己 的 零花钱",
#     "我 说 我 买 股票 了",
#     "他 说   那 你 是 怎么 选择 股票 的",
#     "我 说 我 是 瞎 选 的",
#     "然后 就 没有 然后 了",
#     "其实 当时 我 也 很 迷茫",
#     "我 不 知道 自己 到底 要 从事 一个 什么样 的 行业",
#     "偶然 的 机会 我 到 海淀 黄庄 路过",
#     "我 走 到 人大附中 的 门口",
#     "看到 许多 同学 穿着 校服   在 门口 走来走去",
#     "我 知道 这是 北京 最好 的 高中",
#     "同学 们 要是 逛街 也 要 相约 穿着 校服",
#     "这 好像 构成 了 海淀 黄庄 的 一个 风景线",
#     "我 突然 想到 为什么 不去 做 一名 老师 呢",
#     "我 从 小学 到 中学 到 大学 一直 都 就读于",
#     "中国 当地 最好 的 中学 和 大学",
#     "20 年 的 时间 里",
#     "在 我 25 岁 之前 将近 有 20 年 的 时间",
#     "我 是 在 学校 里 度过 的",
#     "我 喜欢 学校 的 环境",
#     "我 喜欢 上课 的 铃声",
#     "我 喜欢 跟 同学 玩耍",
#     "我 喜欢 幽默 的 老师",
#     "喜欢 不苟言笑 的 教导 主任",
#     "学校 给 我 留下 了 太 多 的 回忆",
#     "而且 我 在 中学 的 时候 学习 还 算 比较 刻苦",
#     "有 很多 自己 的 学习 方法",
#     "而且 我 愿意 跟 同学 分享",
#     "我 还 参加 过 全国 数学 竞赛 和 全国 物理 奥林匹克 竞赛",
#     "也 取得 了 不错 的 成绩",
#     "我 能够 胜任 教学 的 工作",
#     "而且 我 在 大学 的 时候 多次 参加 北京高校 演讲比赛",
#     "并且 获得 冠军",
#     "还 参加 过 国际 大专 辩论赛",
#     "是 中国队 的 辩手",
#     "所以 我 有 优秀 的 表达能力",
#     "可以 在 很多 小朋友 面前 讲话",
#     "而且 不 怯场",
#     "这些 都 是 我 的 优势",
#     "但 最 重要 的 是 我 是 一个 不 善于 与 人 打交道 的 人",
#     "也许 有人 很 奇怪",
#     "你 说 你 善于 表达",
#     "你 又 不 善于 与 人 打交道",
#     "这 不 矛盾 吗",
#     "但是 这 其实 就是 事实",
#     "我 曾经 跟 我 的 同学 争论 一个 问题",
#     "争论 得 面红耳赤",
#     "后来 其他同学 跟 我 说",
#     "在 成人 的 世界 里 是 没有 对错 的",
#     "只有 利弊",
#     "我 明白 他 的 意思",
#     "但是 如果 你 让 我 在职 场上 左右逢源",
#     "媚上 欺下",
#     "见风使舵",
#     "我 真的 做 不到",
#     "于是 有人 跟 我 说",
#     "你 这种 性格 可能 只能 当 一个 中学老师 了",
#     "你 当 一个 中学老师",
#     "讲究 对错 就够 了",
#     "我想通 了",
#     "我 就 想 成为 一名 中学老师",
#     "就 像 我 当时 初中 和 高中 的 老师 那样 精于 业务",
#     "而且 受 学生 尊敬 的 老师",
#     "于是 我 就 向 北京市 的 许多 学校 投了 简历",
#     "经过 几轮 面试",
#     "我 得到 了 四中   景山 和 人大附中 的 offer",
#     "我 记得 在 当时 我 去 人大附中 面试 的 时候",
#     "也 是 一个 类似 的 会场",
#     "先 播放 了 一个 宣传片",
#     "然后 领导 们 讲 讲话",
#     "再 让 自己 准备 一个 课题 上去 试讲 一下",
#     "在 我 试讲 结束 之后",
#     "当时 有 一位 校长 问 了 我 这样 的 一个 问题",
#     "这位 校长 现在 也 在 我们 的 场里",
#     "当时 这位 校长 他 问 了 我 这么 一个 问题",
#     "他 说 我 告诉 你 中学老师 是 一个 非常 辛苦 的 工作",
#     "而且 工资 还 不 高",
#     "你 还 愿意 来 吗",
#     "这个 问题 其实 是 很 难 回答 的",
#     "如果 我 说 我 看中 的 是 北京 户口",
#     "而且 有 寒暑假",
#     "然后 我 再 偷 着 出去 做 家教",
#     "这样 就 可以 挣钱 了",
#     "这 就 显得 很 庸俗",
#     "如果 我 说 我 不在乎 工作 辛苦",
#     "我 也 不在乎 工资 低",
#     "我 就是 要 做 人类 灵魂 的 工程师",
#     "这 显得 很 虚伪",
#     "所以 这个 问题 究竟 该 怎么 回答 呢",
#     "当时 我 的 脑子里 闪现 出 法拉第 的 故事",
#     "只 上 过 两年 小学 的 科学家 法拉第",
#     "年轻 的 时候 自己 在 家里 看书 做 实验",
#     "后来 他 看到 报纸 上大 化学家 戴维招 实验室 助手",
#     "于是 就 来到 了 戴维 的 实验室   戴维问 他",
#     "我 告诉 你 年轻人   科学 是 很 辛苦 的",
#     "而且 没有 多少 回报",
#     "你 还 愿意 来 吗",
#     "法拉第 当时 是 怎么 回答 的 呢",
#     "他 说 我 觉得 科学 本身 就是 一种 回报",
#     "法拉第 是 这么 说 的",
#     "也 是 这么 做 的",
#     "他 把 自己 的 全部 都 献给 了 科学",
#     "终于 通过 自己 的 努力 成为 那个 时代 最 伟大 的 科学家",
#     "于是 我 对 校长 说",
#     "年轻人 不 应该 把 钱 看 得 太重",
#     "更 应该 注重 学习",
#     "人大附中 能 给 我 一个 很 好 的 学习 平台",
#     "在 这里 我 可以 快速 的 成长",
#     "这 是 我 当时 的 心里话",
#     "很 荣幸 从此 之后 就 成为 了 一名 人大附中 的 教师",
#     "我 发现 面试 的 时候 校长 对 我 说 的话",
#     "他 没有 骗 我",
#     "在 附中 的 工作 非常 辛苦",
#     "尤其 是 新 老师",
#     "你 需要 不停 的 备课   上课   批改作业   找 学生 谈话",
#     "还要 经常 上 公开课",
#     "我 在 人大附中 的 前 几年 几乎 都 是 每天 备课 到 12 点 以后",
#     "几年 以后 我 的 备课 量 就 稍微 小 了 一点",
#     "因为 熟练 了",
#     "结果 学校 又 给 我 安排 了 竞赛 的 任务",
#     "备 竞赛 课 更是 辛苦",
#     "你 经常 备出 一节课 就要 花 两三天 的 时间",
#     "我 也 曾经 是 一个 头发 茂密   八块 腹肌 的 青年",
#     "现在 就 变成 这个 样子 了",
#     "不过 有 辛苦   也 有 幸福",
#     "中学生 是 一群 纯洁 的 人",
#     "他们 有 强烈 的 善恶 观",
#     "是非 感",
#     "讲究 对错",
#     "而 非 利弊",
#     "他们 是 一群 理想主义者",
#     "和 他们 在 一起 我 永远 都 不会 感觉 到 自己 已经 老 了",
#     "我会 陪 着 他们 一起 开心   一起 难过",
#     "和 他们 一起 八卦 谁 和 谁 谈恋爱 了",
#     "谁 和 谁 打架 了",
#     "我会 和 他们 一起 开心 解决 一些 很难 的 问题",
#     "设计 一堂 优秀 的 课程",
#     "每 一次 我 都 感觉 到 非常 的 快乐",
#     "我 享受 站 在 台上 的 感觉",
#     "我 享受 同学 们 的 笑声 和 掌声",
#     "我 享受 同学 们 崇拜 的 目光",
#     "这是 许多 工作 不能 给予 我 的 我 的",
#     "我 的 学生 有 的 考上 清华北大",
#     "也 有 的 获得 北京市 状元",
#     "还有 的 获得 了 国际 奥林匹克 竞赛 的 金牌",
#     "我 为此 感觉 到 欣喜若狂",
#     "他们 实现 了 我 当初 没有 实现 的 理想",
#     "他们 的 未来 比 我 更加 辉煌",
#     "而且 他们 还 记得 我   每当 他们 回到 人大附中 的 时候",
#     "会 给 我 讲 他 自己 的 所见所闻",
#     "会 给 我 带来 一些 小 礼物",
#     "谁 说 做 一个 中学教师 是 没有 回报 的 呢",
#     "教师 最大 的 财富 就是 学生",
#     "从 这个 角度 上 讲",
#     "人大附中 让 我 成 了 一名 亿万富翁",
#     "而且 人大附中 不是 一所 普通 的 中学",
#     "它集 了 全 北京市 最好 的 学生",
#     "你 永远 不用 担心 你 自己 的 努力 白费",
#     "精心 准备 的 课程 学生 听不懂",
#     "许多 孩子 的 思维能力 创造 能力 都 比我强",
#     "人大附中 也 是 一所 开放 包容 的 学校",
#     "你 不 需要 在 学校 里 过 多 地 考虑 如何 去 讨好 领导",
#     "只要 你 的 教学 工作 被 人 认可",
#     "不会 有 任何人 刁难 你",
#     "人大附中 是 一所 汇集 了 精英 教师 的 学校",
#     "在 这里 你 会 发现 各种各样 的 人才",
#     "每当 你 遇到困难 的 时候",
#     "都 会 有 其他 的 老师 给 你 做 建议",
#     "帮 你 渡过难关",
#     "人大附中 还是 一所 研究型 的 学校",
#     "我们 有 许多 的 实验室",
#     "一大批 优秀 的 老师 会带 着 更 优秀 的 学生",
#     "进行 科学研究 的 尝试",
#     "人大附中 无论是 老师 还是 学生",
#     "我们 的 发展 都 不会 受到 任何 的 限制",
#     "学校 会 支持 所有 的 创新 的 教学 和 研究 工作",
#     "比如 我 在 2014 年 的 时候 开始 在 网上 放 一些",
#     "自己 的 教学 视频",
#     "2018 年 的 时候 开始 制作 科普 视频",
#     "还 积累 了 一大堆 的 粉丝",
#     "许多 时候 我 录制 视频 是 在 工作 的 闲暇 时间",
#     "而且 还 偷 着 用 了 学校 的 粉笔 和 黑板",
#     "不过 领导 并 没有 说 什么",
#     "而且 领导 还 让 我 在 开会 的 时候",
#     "讲 一 讲 你 自己 为什么 要 这么 做",
#     "我 想 无论是 成为 一名 教师",
#     "还是 我 现在 在 网络 上 做 科普 视频",
#     "都 是因为 我 是 一名 理想主义者",
#     "我 希望 我 能够 把 自己 的 知识 分享 给 更 多 的 人",
#     "让 更 多 的 人 了解 科学 的 乐趣",
#     "而 人大附中 也 正是 一所 理想主义 的 学校",
#     "老师 因材施教",
#     "学生 心无旁骛",
#     "这才 是 做学问",
#     "如果 你 也 是 一名 理想主义者",
#     "人大附中 欢迎 你 的 到来",
#     "谢谢 各位"
#   ]
# }
# {
#   "video_id": "4vbcC4TcMGc",
#   "captions": [
#     "各位 同学 大家 好   我 是 李永乐 老师",
#     "今天 我们 继续 来 研究 黎曼 猜想",
#     "黎曼 猜想 为什么 这么 重要 呢",
#     "因为 它 与 现在 数学 中 的 许多 结论 都 紧密 的 联系 在 一起",
#     "尤其 是 与 质数 的 分布 联系 在 一起",
#     "质数 是 数学界 几千年 以来 一直 非常 感兴趣 的 一个 话题",
#     "现在 的 密码学 也 是 基于 质数 的",
#     "如果 质数 被 人们 彻底 破解   那么 现在 的 密码学 就要 重新 改写",
#     "所谓 的 比特 币   数字 货币 这些 东西 都 要 重新 设计",
#     "那么 质数 到底 有 什么 特点 呢   质数 是 有限 个 还是 无限 个 呢",
#     "它 与 黎曼 猜想 有 什么 关系",
#     "今天 我们 来 稍微 说 一下   我们 首先 来 了解 一下 质数",
#     "什么 叫 质数",
#     "上 小学 的 时候 就 知道",
#     "只有 1 和 它 本身 两个 约数   这种 数 就 叫 质数",
#     "比如说 2 就是 质数   它 只有 1 和 2 两个 约数",
#     "3 也 是 质数   5 也 是 质数   7 也 是 质数",
#     "11 也 是 质数   13 也 是 质数 ...   有 很多 个",
#     "人们 很 早就 在 研究 说 质数 到底 是 有限 个 还是 无限 个 呢",
#     "我们 来看   质数 应该 是 无穷 多个",
#     "质数 有 无穷 多个 这 事 大家 猜 一 猜 是 谁 最早 证明 出来 的",
#     "是 古希腊 的 数学家 欧几里德   ( Euclid )",
#     "这个 欧几里德 怎么 证明 质数 有 无穷 多个 呢",
#     "其实 他 的 证法 非常简单   他用 的 是 反证法",
#     "反正 他 说 假设 质数 是 有限 个",
#     "那么 有限 个 你 一定 能 把 它 列出来   对 不 对",
#     "那 这些 质数 就是   2   3   5   7 ...   p ( 最大 的 质数 )",
#     "然后 他令 有 这么 一个 自然数 等于 2 × 3 × 5 × 7 ... × p + 1",
#     "他令 这么 一个 数",
#     "好 了   咱们 来看 一下 这个 q 的 这个 性质",
#     "说 这个 q 到底 是 质数 还是 合数 呢",
#     "咱们 来看 假如 这个 q 是 一个 质数",
#     "那么 q 也 是 质数   而且 q & gt ; p 那么 它 就 与 什么 矛盾 了",
#     "它 就 与 最 开始 你 所 假设 的 p 是 最大 的 质数 它 矛盾 了   对 不 对",
#     "所以 这个 事儿 不 对   因此 q 不 可能 质数",
#     "那么 如果 q 是 合数 又 如何 呢",
#     "合数 就 是不是 质数 的 数   如果 q 是 合数 又 如何 呢",
#     "q 是 合数   肯定 是 有 约数 的",
#     "而且 这个 约数 既 不是 1 也 不是 它 本身",
#     "约数 应该 是 一个 质数   约数 是 m 它 也 是 一个 质数",
#     "那 我们 知道 这个 约数 是 个 质数",
#     "而 质数 我们 都 找到 了   就是 2357 ... p",
#     "所以 这 m 一定 是 2   3   5   7   ...   p   中间 的 某 一个 数",
#     "那么 问题 来 了",
#     "大家 看 这个 q 它 实际上 是 这些 玩意儿 乘起来 再加 1",
#     "没加 1 之前 这个 数",
#     "它 既 是 2 的 倍数   也 是 3 的 倍数   也 是 5 的 倍数",
#     "加 了 1 之后 它 除以 2 就 会 余 1   对 不 对",
#     "所以 它 不是 2 的 倍数",
#     "除以 3 是不是 也 会 余 1   因为 原来 是 3 的 整数倍",
#     "你加 了 1 那 肯定 除以 3 余 1",
#     "你 要是 除以 5 是不是 还余 1",
#     "所以 它 除以 所有 这些 个 质数",
#     "结果 都 会 余下 一个 1   而 不是 整数倍",
#     "因此 你 现在 说 有 约数 m 它 是 个 质数   这 又 矛盾 了",
#     "因此 这个 q 既 不能 是 质数 也 不能 是 合数   它们 两个 之间 就 矛盾 了",
#     "那么 这种 矛盾 的 最 根本原因 是 你 假设 有限 个 质数",
#     "所以 质数 是 无穷 多个",
#     "你 看 这个 证法 其实 还是 挺 简洁 的   对 吧   非常 的 漂亮",
#     "虽然 人们 很 早就 知道 质数 有 无穷 多个",
#     "但是 质数 到底 是 怎么 分布 的",
#     "我们 能 不能 从前 一个 质数 推出 后 一个 质数",
#     "这是 人们 一直 在 寻找 的 方法   但是 都 没有 找到",
#     "那么 在 古代 的 时候 人们 是 怎么 获得 质数 的 呢",
#     "比如说 有 一个 古希腊 的 人   他 其实 是 埃及 人",
#     "但是 是 在 古希腊 时期 的",
#     "这个 埃及 人 名字 叫 埃拉 托色尼 ( Eratosthenes )",
#     "大家 对 这个 名字 有 印象 吗",
#     "埃拉 托色尼 其实 就是 测出 地球 半径 的 那个 人",
#     "以前 我们 也 讲 过 这个 人",
#     "这个 埃拉 托色尼 他 提出 了 一种 方法 就是 埃拉 托色尼 筛选 法",
#     "通过 这种 方法 我们 可以 很 方便 地 得到 一个 质数 的 表格",
#     "比如说 吧   我们 想 知道 1   2   3   4   5   ...   16",
#     "比如 我们 就 知道 这 16 个数",
#     "我 就 想 问   这 16 个数 里边 哪些 是 质数   哪些 是 合数",
#     "我们 怎么 判断",
#     "这个 埃拉 托色尼 这么 说",
#     "他 说 吧   首先 你 把 最大 的 这个 数开 根号",
#     "比如说 16   你 开 根号 就是 4",
#     "17 的话 开 根号 就是 4 点多   对 不 对",
#     "然后 你 把 这个 求 出 一个 什么 呀   求 出 一个 √ n 来",
#     "求 出 一个 √ n 来 这 是 你 的 第一步",
#     "第二步   你 把 这个 小于 √ n 的 质数 它 的 倍数 给 划掉",
#     "剩下 的 就 全都 是 质数 了   为什么 要 这么 干 呢",
#     "这 是因为 人们 发现 如果 最大 那个 数是 n 的话",
#     "那么 这个 n 有 很多 个 约数",
#     "其中 比较 小 的 那个 约数 肯定 会 小于 √ n   这是 一定 的",
#     "然后 我 就 把 小于 根号 里面 所有 的 质数 的 倍数 全都 划掉",
#     "这样 剩下 的 那些 数 就 全都 没有 约数 了",
#     "于是 它 就 变成 了 一个 质数",
#     "比如说 我们 首先 把 这个 最大 的 数 16 开 根号",
#     "开 根号 这 就是 4   对 吧",
#     "我们 把 不 大于 4 的 质数 的 倍数 越约 掉",
#     "不 大于 4 的 质数 有 几个   就 俩",
#     "一个 2   一个 3   对 吧",
#     "首先 我们 先 把 2 的 倍数 约 掉",
#     "注意 2 不要 划   把 4 划掉   把 6 划掉",
#     "8   10   12   14   16   好   划掉 了",
#     "划掉 之后 我们 再 把 3 的 倍数 划掉",
#     "3 不要 划   3 的 倍数 有 6   6 已经 划掉",
#     "9   9 划掉   12   12 已经 划掉 了",
#     "15   15 划掉   好   我们 还 剩 一个 数",
#     "1 既 不是 质数 也 不是 合数",
#     "所以 这个 数 我们 也 不要   还 剩下 的 数 就 全都 是 质数 了",
#     "哪些 数是 质数   你 看 2   3   5   7   11   13 对 吧",
#     "这 几个 数 就是 质数 了",
#     "当然 我们 会 发现 这种 方法 其实 还是 比较 笨 的",
#     "我们 想求 出 一个 大数 到底 是不是 质数 这么 干 其实 很 繁琐",
#     "有没有 什么 更好 的 方法 来 研究 质数 的 分布 呢",
#     "中世纪 的 时候 数学 没什么 太 大 发展",
#     "直到 后来 神人 欧拉 出现 了",
#     "才 终于 又 把 质数 的 研究 向前 推进 了 一步",
#     "我们 在 上 回 的 时候 讲到 了 欧拉 求出 了 一个 级数",
#     "这个 级数 叫 ε ( s ) = 1 / 1 ^ s + 1 / 2 ^ s + 1 / 3 ^ s +...   对 不 对",
#     "欧拉 通过 研究 这个 级数 得到 了 一个 著名 的 公式",
#     "叫 欧拉 乘积 公式",
#     "叫 ε ( s ) 它 等于 什么 呢   它 等于 连乘 ( 1 - p ^ - s ) ^ - 1",
#     "其中 p 是 全体 质数   有人 说 这 什么 玩意儿",
#     "我们 简单 的 解释一下 左边 就是 上面 这个 含义",
#     "这个 我们 就 不 多 说 了",
#     "而 右边 这个 符号 是 连乘   就是 一个 乘 一个",
#     "p 是 全体 的 质数   所以 这个 事 我们 把 它 写 开 大概 是 这个 样子",
#     "第一个 质数 是 2   对 吧",
#     "1 / ( 1 - 1 / 2 ^ s )   这 就是 第一项",
#     "第二项   第二个 质数 不是 3 吗   就是 1 / ( 1 - 1 / 3 ^ s )",
#     "第三个 质数 是 5   1 / ( 1 - 1 / 5 ^ s )",
#     "一直 乘   把 所有 的 质数 全都 乘起来",
#     "乘 完 了 之后 就 等于 上面 这个 数 了",
#     "而且 我们 又 知道 上面 这个 级数",
#     "它 如果 解析 延拓 就是 黎曼 函数   对 不 对",
#     "所以 黎曼 函数 就 与 质数 有 某种 隐含 的 关系",
#     "那 现在 人们 发现 黎曼 函数 与 质数 的 关系 比 这个 要 多得多",
#     "其实 欧拉 还 发现 了 一件 事",
#     "他 通过 研究 这个 函数 发现 π ( x )",
#     "什么 叫 π ( x )   就是 小于 x 的 所有 质数 的 个数 叫 π ( x )",
#     "质数 的 个数 约等于 多少 呢   约等于 x / ln ( x )",
#     "所以 我们 可以 大概 的 估计 一下",
#     "这个 小于 x 的 质数 到底 有 多少 个   对 吧",
#     "欧拉 研究 到 这 之后 就 鸣金收兵 了   搞 别的 去 了",
#     "所以 他 没有 继续 往 下",
#     "没有 提出 关于 质数 分布 的 更加 详细 的 定理",
#     "那么 这个 荣耀 就 属于 后面 的 数学家 了",
#     "这个 就 叫 素数 定理 或者 叫 质数 定理",
#     "这个 质数 定理 和 素数 定理 到底 谁 提出 来 的 呢",
#     "首先 我们 要说 一个 人物 就是",
#     "高斯 ( Johann   Carl   Friedrich   Gauss   1777 - 1855 )",
#     "高斯 是 与 欧拉 齐名 的 数学家",
#     "那么 高斯 在 小 的 时候 就 对 数学 非常 痴迷",
#     "比如 他 小 的 时候 玩游戏   玩 什么游戏 呢",
#     "你 说 我 现在 玩 王者 荣耀   是 吧   我 现在 玩 吃 鸡",
#     "人家 高斯 15 岁 的 时候 玩 的 游戏 可 高级 了",
#     "他 在 数轴 上 怎么样 呢   找 一个 段",
#     "这 一段 一共 有 1000 个数",
#     "他 把 这 1000 个数 里面 所有 的 质数 都 找 出来   数数 有 几个",
#     "然后 我们 用 质数 的 个数 除以 1000",
#     "看一看 质数 分布 的 密度 有 多少",
#     "他 没事 找 1000 个   没事 找 1000 个",
#     "结果 最后 欧拉 （ 应该 是 高斯 ） 就 发现 什么 呢",
#     "说 这个 质数 的 密度 它 约等于 1 / ln ( x )   约等于 这个 事",
#     "那 这 是 高斯 在 小 的 时候 就 得到 的 一个 猜想",
#     "但 他 没有 写 出来",
#     "他 虽然 知道 了 这件 事 之后 他 没有 把 它 写 出来",
#     "因为 它 的 内容 实在 太多 了   他 觉得 这个 东西 微 不足",
#     "所以 他 不足以 去 写",
#     "于是 有 一个 法国 的 数学家 名字 叫勒 让 德",
#     "这个 勒 让 德 （ 法语 ： Adrien - Marie   Legendre   1752 - 1833 ）",
#     "在 1798 年 的 时候 就 提出 了 素数 定理",
#     "素数 定理 是 说 的 什么",
#     "他 说   不 大于 x 的 质数 的 个数   等于 什么 呢",
#     "等于 1 个 积分",
#     "从 0 积分 到 x   dt / ln ( t ) + C",
#     "也就是说 不 大于 x 的 质数 个数",
#     "我们 大概 可以 通过 一个 积分 式 进行 求解",
#     "而 这个 东西 其实 已经 用到 了 欧拉 的 这种 思想   对 吧",
#     "但是 它 是 勒 让 德 最早 提出 来 的",
#     "结果 高斯 在 1849 年 的 时候   已经 过 了 50 年 了",
#     "这个 时候 高斯 给 别人 写信 说 其实 他 早就 发现 了 这件 事",
#     "又 把 这个 勒 让 德 的 功劳 揣到 自己 兜里 了",
#     "有人 说 那 这 也 行 吗   这个 因为 他 是 高斯 他 就 行",
#     "你 要是 别人 就 不行   对 吧",
#     "别人 相信 高斯 的 名望",
#     "没有 必要 去 把 这个 小小的 功劳 揣到 自己 的 兜里",
#     "所以 他 这个 事 应该 就是 他 发现 的",
#     "所以 人们 就 把 这 公式 叫勒 让 德 - 高斯 公式",
#     "好   这 两个 东西 得到 这么 一个 结果",
#     "这个 结果 到底 对 还是 不 对 呢   不 知道",
#     "所以 它 称之为 一个 猜想",
#     "这个 猜想 就 叫 素数 猜想   那么 后来 为什么 叫 素数 定理 了 呢",
#     "是因为 又 过 了 50 年 左右 有 一个 数学家 把 它 证明 出来 了",
#     "这个 数学家 怎么 把 它 证明 出来 的",
#     "就是 在 研究 黎曼 猜想 的 时候 顺便 就 把 素数 猜想 给 证明 出来 了",
#     "所以 可见 这个 黎曼 猜想 和 素数 的 这个 关系 是 非常 非常 紧密 的",
#     "那么 这个 剩余 的 这 一项 C 到底 是 多 大 呢",
#     "有 一个 数学家 科赫 就 指出 了 这样 一个 问题",
#     "就是 科赫 雪花 那个 科赫",
#     "他 说 如果 黎曼 猜想 能够 被 证实 的话",
#     "这个 余项 C ～ √ xln ( x )",
#     "如果 你 黎曼 猜想 被 证实 了",
#     "我们 就 可以 把 这个 范围 缩小 到 这么样 一个 程度",
#     "那 人们 对于 质数 的 理解 就 更加 深刻 了",
#     "当然 即便 黎曼 猜想 被 证实",
#     "我们 也 不 能够 完全 得到 素数 的 全部 规律",
#     "素数 的 规律 肯定 还 需要 很多很多年 数学家 们 的 探索",
#     "也许 素数 就是 宇宙 给 人们 的 密码",
#     "说 了 这么 多",
#     "明天 我们 终于 要 给 大家 介绍 黎曼 猜想 到底 是 什么 了",
#     "大家 如果 喜欢 我 的 视频",
#     "可以 在 西瓜 视频 和 YouTube 帐号 李永乐 老师 里 关注 我"
#   ]
# }
