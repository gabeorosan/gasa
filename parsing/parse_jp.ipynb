# %%
from langtools import *
folder_path = '../lyrics/jp'
artists = ['Yorushika',  'myuk','Nico Touches the Walls', 'King Gnu']
generate_txt(artists, folder_path)
# Out:
# Searching for songs by Yorushika...
#
# Changing artist name to 'ヨルシカ (Yorushika)'
# Song 1: "嘘月 (Liar)"
# Song 2: "ヒッチコック (Hitchcock)"
# Song 3: "だから僕は音楽を辞めた (That’s Why I Gave Up on Music)"
# Song 4: "言って。(Say It.)"
# Song 5: "斜陽 (Setting Sun)"
# Song 6: "左右盲 (Left-Right Confusion)"
# Song 7: "春泥棒 (Spring Thief)"
# Song 8: "花に亡霊 (Ghost In A Flower)"
# Song 9: "風を食む (Eat the Wind)"
# Song 10: "ただ君に晴れ (Just a Sunny Day for You)"
# Song 11: "強盗と花束 (Robber And Bouquet)"
# Song 12: "夜行 (Night Journey)"
# Song 13: "花人局 (Flower And Badger Game)"
# Song 14: "憂一乗 (Only Sorrow)"
# Song 15: "藍二乗 (Deep Indigo)"
# Song 16: "落下 (Falling)"
# Song 17: "又三郎 (Matasaburo)"
# Song 18: "前世 (Past Life)"
# Song 19: "春ひさぎ (Prostitution)"
# Song 20: "盗作 (Plagiarism)"
# Song 21: "思想犯 (Thoughtcrime)"
# Song 22: "昼鳶 (Burglar)"
# Song 23: "老人と海 (The Old Man and the Sea)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-8-31-lyrics
# Song 24: "8/31"
# Song 25: "都落ち (Miyakoochi)"
# Song 26: "レプリカント (Replicant)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-confession-of-plagiarist-lyrics
# Song 27: "音楽泥棒の自白 (Confession of Plagiarist)"
# Song 28: "靴の花火 (Fireworks Beneath My Shoes)"
# Song 29: "逃亡 (Escape)"
# Song 30: "月に吠える (Howl at the Moon)"
# Song 31: "負け犬にアンコールはいらない (A Loser Doesn’t Need an Encore)"
# Song 32: "爆弾魔 Re-Recording (Bomber)"
# Song 33: "451"
# Song 34: "ブレーメン (Bremen)"
# Song 35: "テレパス (Telepath)"
# Song 36: "パレード (Parade)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-adolescent-burglar-lyrics
# Song 37: "青年期, 空き巣 (Adolescent, Burglar)"
# Song 38: "詩書きとコーヒー (Songwriting and Coffee)"
# Song 39: "アルジャーノン (Algernon)"
# Song 40: "第一夜 (Dai Ichiya)"
# Song 41: "雨とカプチーノ (Rain with Cappuccino)"
# Song 42: "神様のダンス (Dance of You)"
# Song 43: "夏の肖像 (Natsu no Shouzou)"
# Song 44: "雲と幽霊 (The Clouds and the Ghost)"
# Song 45: "八月、某、月明かり (August, A Certain Person, Moonlight)"
# Song 46: "創作 (Creation)"
# Song 47: "さよならモルテン (Sayonara Molten)"
# Song 48: "夜紛い (Yoru Magai)"
# Song 49: "いさな (Isana)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-middle-age-plagiarist-lyrics
# Song 50: "朱夏期, 音楽泥棒 (Middle Age, Plagiarist)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-summer-bus-stop-waiting-for-you-lyrics
# Song 51: "夏、バス停、君を待つ (Summer, Bus Stop, Waiting for You)"
# Song 52: "ノーチラス (Nautilus)"
# Song 53: "準透明少年 (Semi-Transparent Boy)"
# Song 54: "心に穴が空いた (Hole In The Heart)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-playing-piano-in-the-shadow-of-summer-lyrics
# Song 55: "夏陰、ピアノを弾く (Playing Piano in the Shadow of Summer)"
# Song 56: "雨晴るる (After the Rain)"
# Song 57: "冬眠 (Hibernation)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-seabed-moonlight-lyrics
# Song 58: "海底、月明かり (Seabed, Moonlight)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-childhood-in-memories-lyrics
# Song 59: "幼年期, 思い出の中 (Childhood, In Memories)"
# Song 60: "Make-up Shadow"
# Song 61: "夕凪、某、花惑い (Evening Calm, Somewhere, Fireworks)"
# Song 62: "声 (Voice)"
# Song 63: "五月は花緑青の窓辺から (Gogatsu wa Hana Rokushou no Madobe Kara)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-train-window-lyrics
# Song 64: "車窓 (Train Window)"
# Song 65: "カトレア (Cattleya)"
# Song 66: "エルマ (Elma)"
# Song 67: "エイミー (Amy)"
# Song 68: "六月は雨上がりの街を書く (Rokugatsu wa Ameagari no Machi wo Kaku)"
# Song 69: "パドドゥ (Pas de Deux)"
# Song 70: "の夏に咲け (Blooming in That Summer)"
# Song 71: "雪国 (Yukiguni)"
# Song 72: "歩く (Walk)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-flying-free-lyrics
# Song 73: "飛行 (Flying Free)"
# Song 74: "踊ろうぜ (Let’s Dance)"
# Song 75: "チノカテ (Chinokate)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-4-10-lyrics
# Song 76: "4/10"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-church-in-the-forest-lyrics
# Song 77: "森の教会 (Church in the Forest)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-lakeside-town-lyrics
# Song 78: "湖の街 (Lakeside Town)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-5-6-lyrics
# Song 79: "5/6"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Yorushika-7-13-lyrics
# Song 80: "7/13"
# Song 81: "あの夏に咲け (Ano Natsu ni Sake)"
# Song 82: "藍二乗 (Deep Indigo) (Romanized)"
# Done. Found 82 songs.
# Searching for songs by myuk...
#
# Changing artist name to 'Myuk'
# Song 1: "魔法 (Mahou)"
# Song 2: "愛の唄 (Ai no Uta)"
# Song 3: "シオン (Sion)"
# Song 4: "Pancake"
# Song 5: "魔法 (Mahou) (Whales Remix) - SACRA BEATS Singles"
# Song 6: "あふれる (A Fu Re Ru)"
# Song 7: "Set Me Free"
# Song 8: "シオン (Sion) (Ngyn Remix) - SACRA BEATS Singles"
# Song 9: "フェイクファーワルツ (Fakefur Waltz)"
# Done. Found 9 songs.
# Searching for songs by Nico Touches the Walls...
#
# Changing artist name to 'NICO Touches the Walls'
# Song 1: "ホログラム (Hologram)"
# Song 2: "Broken Youth"
# Song 3: "Diver - Naruto Shippuden (Romanticized)"
# Song 4: "Diver"
# Song 5: "Passenger"
# Song 6: "Not Even Giving In To the Rain - Naruto Shippuden (Romanticized)"
# Song 7: "Survive"
# Song 8: "Anytime, Anywhere"
# Song 9: "マシ・マシ (Mashi Mashi)"
# "Diver (instrumental)" is not valid. Skipping.
# Song 10: "天地ガエシ (Tenchi Gaeshi)"
# Song 11: "The Bungy"
# Song 12: "Image Training"
# Song 13: "(My Sweet) Eden"
# Song 14: "B.C.G"
# Song 15: "Ganimata Girl"
# Song 16: "Yoru No Hate (夜の果て)"
# Done. Found 16 songs.
# Searching for songs by King Gnu...
#
# Song 1: "一途 (Ichizu)"
# Song 2: "白日 (Hakujitsu)"
# Song 3: "Prayer X"
# Song 4: "カメレオン (Chameleon)"
# Song 5: "Teenager Forever"
# Song 6: "どろん | Doron"
# Song 7: "壇上 | Danjou"
# Song 8: "ユーモア | Humor"
# Song 9: "逆夢 (Sakayume)"
# Song 10: "三文小説 (Sanmon Shosetsu)"
# Song 11: "Vinyl"
# Song 12: "飛行艇 (Hikoutei)"
# Song 13: "千両役者 (Senryo Yakusha)"
# Song 14: "Overflow"
# Song 15: "Tokyo Rendez-Vous"
# Song 16: "傘 | Umbrella"
# Song 17: "小さな惑星 | Small Planet"
# Song 18: "McDonald Romance"
# Song 19: "雨燦々(Ame Sansan)"
# Song 20: "ロウラヴ (Low Love)"
# Song 21: "BOY"
# Song 22: "あなたは蜃気楼 | Anata wa Shinkirou"
# Song 23: "サマーレイン·ダイバー | Summer Rain Diver"
# Song 24: "破裂 | Haretsu"
# Song 25: "Stardom"
# Song 26: "開会式 | Opening Ceremony"
# Song 27: "泡 (ABUKU)"
# Song 28: "The hole"
# Song 29: "Don’t Stop the Clocks"
# Song 30: "SPECIALZ"
# Song 31: "Night Pool"
# Song 32: "飾りじゃないのよ 涙は | Kazari janai no yo namida wa"
# Song 33: "幕間 | Interlude"
# Song 34: "Sympa I"
# Song 35: "Hitman"
# Song 36: "F.O.O.L"
# Song 37: "Slumberland"
# Song 38: "閉会式 | Closing Ceremony"
# Song 39: "Prayer X (Acoustic)"
# Song 40: "Sorrows"
# Song 41: "Flash!!!"
# Song 42: "It’s a small world"
# Song 43: "Bedtown"
# Song 44: "Hakujitsu Dio Cover (Romanized)"
# Song 45: "Sympa IV"
# "カメレオン (Chameleon) (Instrumental)" is not valid. Skipping.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/King-gnu-sympa-ii-lyrics
# Song 46: "Sympa II"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/King-gnu-sympa-iii-lyrics
# Song 47: "Sympa III"
# "硝子窓 (Garasu Mado)" is not valid. Skipping.
# "Stardom -Instrumental-" is not valid. Skipping.
# Done. Found 47 songs.
# 154

# %%
title_ids = read_title_ids()
missing_ids = jp_txt_json(folder_path, title_ids)
# Out:
# 33 Missing ids
# Total songs: 108

# %%
missing_ids = jp_txt_json(folder_path, title_ids)
# Out:
# 0 Missing ids
# Total songs: 108

# %%
title_ids = update_missing(title_ids, missing_ids)

# %%
write_title_ids(title_ids)
